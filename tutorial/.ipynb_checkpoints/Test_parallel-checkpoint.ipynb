# %% [markdown]
# # Test Parallel Processing
#
# This script is used to test whether the parallel processing works in [the docker image](https://hub.docker.com/r/hcp4715/hddm). It includes two parts:
# * Part 1: test parallel processing using easy calculations
# * Part 2: test parallel processing using HDDM's modelling
#
# **Please make sure that you started multiple engines at the IPython Cluster**
#
#
# **Note**: Example data are from [Hu et al. (2020)'s Experiment 2](https://collabra.org/articles/10.1525/collabra.301/). This data can be downloaded from [github](https://github.com/hcp4715/moralSelf_ddm/blob/master/2_confirm_study/Results/3_hddm/MS_match_hddm_stim.csv) too.

# %%
# check which python is in use.
import sys
print('Notebook is running:', sys.executable) # /opt/conda/bin/python

# or uncomment the code below
from platform import python_version # 3.7.6

print('The current Python version is', python_version())

import hddm, IPython
print('The current HDDM version is', hddm.__version__) # 0.8.0

# Warning:`IPython.parallel` package has been deprecated since IPython 4.0. 
#print('The current IPython version is', IPython.__version__) 

import os
cur_dir = os.getcwd()
print('The current working directory is', cur_dir)
# Out:
# Notebook is running: /opt/conda/bin/python
# The current Python version is 3.7.6
# The current HDDM version is 0.8.0
# The current working directory is /home/jovyan/example
# /opt/conda/lib/python3.7/site-packages/IPython/parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated since IPython 4.0. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)

# %% [markdown]
# ## Part 1: testing ipyparallel
#
# Test computing using examples from this [tutorial](http://people.duke.edu/~ccc14/sta-663-2016/19C_IPyParallel.html).

# %%
import ipyparallel as ipp
rc = ipp.Client()
rc.ids
# Out:
# [0, 1, 2, 3]

# %%
def foo():
    import time
    time.sleep(5)
    return 'foo'

def bar():
    import time
    time.sleep(10) 
    return 'bar'  

res1 = rc[0].apply(foo)
res2 = rc[1].apply(bar)
results = [res1, res2]

while not all(map(lambda ar: ar.ready(), results)):
    pass

print(res1.get(), res2.get())
# Out:
# foo bar

# %%
dv = rc[:]

res = dv.map(lambda x, y, z: x + y + z, range(10), range(10), range(10))
res.get()
# Out:
# [0, 3, 6, 9, 12, 15, 18, 21, 24, 27]

# %%
@dv.remote(block = True)
def f1(n):
    import numpy as np
    return np.random.rand(n)
f1(4)
# Out:
# [array([0.50871237, 0.37371268, 0.77810576, 0.23172814]),
#  array([0.32515526, 0.09865422, 0.09489759, 0.52831638]),
#  array([0.17325693, 0.29148397, 0.57639238, 0.4248499 ]),
#  array([0.04744856, 0.60286768, 0.47335949, 0.4056023 ])]

# %% [markdown]
# ## Part 2: Test parallel processing using HDDM's func

# %%
# %matplotlib inline

# Preparation
import os, time, csv, datetime
import kabuki, hddm
from kabuki.analyze import gelman_rubin

from datetime import date

import random
import pandas as pd
import matplotlib.pyplot as plt

# %%
# check the data
# load data
df = hddm.load_csv('df_example.csv')
df.head(10)  # uncomment if you want to check the head of the data
# Out:
#    subj_idx     match   val     id  stim  response      rt
# 0      7304  mismatch   Bad  Other     0         1  0.7247
# 1      7304  mismatch   Bad   Self     0         0  0.8786
# 2      7304     match  Good  Other     1         1  0.8167
# 3      7304     match   Bad  Other     1         0  0.8728
# 4      7304  mismatch  Good  Other     0         1  0.6849
# 5      7304  mismatch   Bad   Self     0         1  0.6951
# 6      7304     match  Good   Self     1         1  0.4951
# 7      7304     match   Bad  Other     1         0  0.8713
# 8      7304     match  Good   Self     1         1  0.5954
# 9      7304     match   Bad  Other     1         1  0.6875

# %%
# Uncomment the codes below if you are interested in checking the distribution of raw data
# plot and save the distribution of raw data:
fig = plt.figure()
ax = fig.add_subplot(111, xlabel='RT', ylabel='count', title='RT distributions')
for i, subj_data in df.groupby('subj_idx'):
    subj_data.rt.hist(bins=20, histtype='step', ax=ax)

# %%
# define a function to run model in parallel
def run_model(id):
    print('running model%i'%id);
    
    import hddm
    import random
    #import os
    
    #cur_dir = os.getcwd()

    exp_name = 'example'
    print('running models %i'%id, 'for for exp', exp_name)
    
    # USE the absolute directory in docker.
    dbname = '/home/jovyan/example/df_' + exp_name + '_chain_vaz_test_%i.db'%id # define the database name, which uses pickle format
    mname  = '/home/jovyan/example/df_' + exp_name + '_chain_vaz_test_%i'%id    # define the name for the model
    fname  = '/home/jovyan/example/df_' + exp_name + '.csv'
    df = hddm.load_csv(fname)

    df_subj = df['subj_idx'].unique()

    # random select without repetition
    random.seed(10)
    df_test_list = []
    for i in range(10):
        pos = random.randint(0, (len(df_subj)-1))
        df_test_list.append(df_subj[pos])  
    
    df_test = df[df['subj_idx'].isin(df_test_list)]
    
    m = hddm.HDDMStimCoding(df_test, 
                            include='z', 
                            stim_col='stim', 
                            depends_on={'v':['match','val', 'id']},
                            split_param='v', 
                            drift_criterion=False,
                            p_outlier=0.05)
    m.find_starting_values()
    m.sample(500, burn=100, dbname=dbname, db='pickle')
    m.save(mname)
    
    return m

# %% [markdown]
# ### Test the docker image: Single chain

# %%
start_time = time.time()  # the start time of the processing

m = run_model(0)

print("\nRunning 1 chain used: %f seconds." % (time.time() - start_time))
# Out:
# running model0
# running models 0 for for exp example
# /opt/conda/lib/python3.7/site-packages/scipy/optimize/optimize.py:1985: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
#  [-----------------100%-----------------] 501 of 500 complete in 164.0 sec
# Running 1 chain used: 177.769620 seconds.

# %%
print("M_df1a_v_corr DIC: %f" % m.dic)
# Out:
# M_df1a_v_corr DIC: 648.257419

# %% [markdown]
# ### Test the docker image: Multiple chains in parallel

# %%
from ipyparallel import Client

v = Client()[:]

start_time = time.time()  # the start time of the processing

jobs = v.map(run_model, range(4)) # 4 is the number of CPUs
models = jobs.get()

print("\nRunning 4 chains used: %f seconds." % (time.time() - start_time))
# Out:
# Running 4 chains used: 230.557756 seconds.

# %%
print("M_df1a_v_corr DIC: %f" % models[0].dic) 

gelman_rubin(models)
# Out:
# M_df1a_v_corr DIC: 648.517118
# {'a': 1.0012887564618325,
#  'a_std': 1.0036716134956367,
#  'a_subj.7304': 0.9998468750398468,
#  'a_subj.7306': 1.0041878020130555,
#  'a_subj.7317': 1.0002168933184974,
#  'a_subj.7321': 1.0035459065656966,
#  'a_subj.7332': 1.0026815717496,
#  'a_subj.7334': 1.0043758317163405,
#  'a_subj.7335': 1.0037303387602963,
#  'a_subj.7336': 0.9994002102328599,
#  'a_subj.7340': 1.0017061157520575,
#  'v(Other.match.Bad)': 1.001755324775684,
#  'v(Other.match.Good)': 1.0020248310805075,
#  'v(Other.mismatch.Bad)': 0.9993039433719719,
#  'v(Other.mismatch.Good)': 1.0005533843351104,
#  'v(Self.match.Bad)': 1.0006986263097917,
#  'v(Self.match.Good)': 1.001790387221414,
#  'v(Self.mismatch.Bad)': 0.999006542479937,
#  'v(Self.mismatch.Good)': 0.9990348510333634,
#  'v_std': 1.0019841474436268,
#  'v_subj(Other.match.Bad).7304': 1.0040815146129818,
#  'v_subj(Other.match.Good).7304': 0.9998405388613107,
#  'v_subj(Other.match.Bad).7306': 1.0015121792619028,
#  'v_subj(Other.match.Good).7306': 1.0064950171246905,
#  'v_subj(Other.match.Bad).7317': 0.9996969859345562,
#  'v_subj(Other.match.Good).7317': 0.999922797351353,
#  'v_subj(Other.match.Bad).7321': 1.0029609170355327,
#  'v_subj(Other.match.Good).7321': 1.0027037251447546,
#  'v_subj(Other.match.Bad).7332': 1.0001740400546155,
#  'v_subj(Other.match.Good).7332': 1.0042437142475908,
#  'v_subj(Other.match.Bad).7334': 1.0015307028675078,
#  'v_subj(Other.match.Good).7334': 1.0026548829246729,
#  'v_subj(Other.match.Bad).7335': 1.002375683735738,
#  'v_subj(Other.match.Good).7335': 1.003460027284553,
#  'v_subj(Other.match.Bad).7336': 1.0000171557567745,
#  'v_subj(Other.match.Good).7336': 1.0002433235854034,
#  'v_subj(Other.match.Bad).7340': 0.999253235226083,
#  'v_subj(Other.match.Good).7340': 0.999916400458797,
#  'v_subj(Other.mismatch.Bad).7304': 1.0012854161948697,
#  'v_subj(Other.mismatch.Good).7304': 1.0050508546277217,
#  'v_subj(Other.mismatch.Bad).7306': 1.0016123842198599,
#  'v_subj(Other.mismatch.Good).7306': 0.9997437769931206,
#  'v_subj(Other.mismatch.Bad).7317': 1.0012749962265626,
#  'v_subj(Other.mismatch.Good).7317': 1.0000001555357092,
#  'v_subj(Other.mismatch.Bad).7321': 1.002292664809547,
#  'v_subj(Other.mismatch.Good).7321': 1.0004103708950087,
#  'v_subj(Other.mismatch.Bad).7332': 1.000655221353149,
#  'v_subj(Other.mismatch.Good).7332': 1.0035258275580252,
#  'v_subj(Other.mismatch.Bad).7334': 1.0022165021556624,
#  'v_subj(Other.mismatch.Good).7334': 0.9992270108572112,
#  'v_subj(Other.mismatch.Bad).7335': 1.0002489164079966,
#  'v_subj(Other.mismatch.Good).7335': 1.0012838712343892,
#  'v_subj(Other.mismatch.Bad).7336': 1.0030882648091035,
#  'v_subj(Other.mismatch.Good).7336': 0.998976476537653,
#  'v_subj(Other.mismatch.Bad).7340': 0.998791678323177,
#  'v_subj(Other.mismatch.Good).7340': 0.9997409638360248,
#  'v_subj(Self.match.Bad).7304': 1.0011959003509965,
#  'v_subj(Self.match.Good).7304': 1.0038225041617934,
#  'v_subj(Self.match.Bad).7306': 1.0007356338606679,
#  'v_subj(Self.match.Good).7306': 0.9996257910592161,
#  'v_subj(Self.match.Bad).7317': 0.9991584536619623,
#  'v_subj(Self.match.Good).7317': 0.999043212693256,
#  'v_subj(Self.match.Bad).7321': 1.0051035290600154,
#  'v_subj(Self.match.Good).7321': 1.0018694422841574,
#  'v_subj(Self.match.Bad).7332': 0.999379747721643,
#  'v_subj(Self.match.Good).7332': 1.0012333505043185,
#  'v_subj(Self.match.Bad).7334': 1.0010393978552798,
#  'v_subj(Self.match.Good).7334': 1.0006773110422635,
#  'v_subj(Self.match.Bad).7335': 1.0005366351580995,
#  'v_subj(Self.match.Good).7335': 1.0071303806075267,
#  'v_subj(Self.match.Bad).7336': 1.0021153617733083,
#  'v_subj(Self.match.Good).7336': 1.0048657499258895,
#  'v_subj(Self.match.Bad).7340': 0.9989582824734883,
#  'v_subj(Self.match.Good).7340': 1.0067497669938383,
#  'v_subj(Self.mismatch.Bad).7304': 1.0003254307028686,
#  'v_subj(Self.mismatch.Good).7304': 1.0032622761467898,
#  'v_subj(Self.mismatch.Bad).7306': 0.9995574702728776,
#  'v_subj(Self.mismatch.Good).7306': 1.0019837734441455,
#  'v_subj(Self.mismatch.Bad).7317': 1.0024130015524555,
#  'v_subj(Self.mismatch.Good).7317': 0.9993520525609754,
#  'v_subj(Self.mismatch.Bad).7321': 1.0002761975742167,
#  'v_subj(Self.mismatch.Good).7321': 1.0037236533407128,
#  'v_subj(Self.mismatch.Bad).7332': 1.0041327065096688,
#  'v_subj(Self.mismatch.Good).7332': 1.0037222443549454,
#  'v_subj(Self.mismatch.Bad).7334': 0.9995392085399716,
#  'v_subj(Self.mismatch.Good).7334': 0.9995320603941903,
#  'v_subj(Self.mismatch.Bad).7335': 0.9990140298844854,
#  'v_subj(Self.mismatch.Good).7335': 1.002877817159713,
#  'v_subj(Self.mismatch.Bad).7336': 1.0006407058977649,
#  'v_subj(Self.mismatch.Good).7336': 1.0018616190840968,
#  'v_subj(Self.mismatch.Bad).7340': 0.9999464388711647,
#  'v_subj(Self.mismatch.Good).7340': 1.0030558512095265,
#  't': 0.9997991472632243,
#  't_std': 1.0033785748320738,
#  't_subj.7304': 1.0010332529457246,
#  't_subj.7306': 1.0013593191733763,
#  't_subj.7317': 1.0006267109520979,
#  't_subj.7321': 1.0085708859578166,
#  't_subj.7332': 1.0020040947692337,
#  't_subj.7334': 1.0081819489365687,
#  't_subj.7335': 1.0008118802268264,
#  't_subj.7336': 1.0032436399520883,
#  't_subj.7340': 1.0031290833467457,
#  'z_trans': 1.0229262695114902,
#  'z_std': 1.0167452757326774,
#  'z_subj_trans.7304': 1.02346550954077,
#  'z_subj_trans.7306': 1.0104313050958649,
#  'z_subj_trans.7317': 0.9998185545546812,
#  'z_subj_trans.7321': 1.0184520388963825,
#  'z_subj_trans.7332': 1.008196977017875,
#  'z_subj_trans.7334': 1.004798725505316,
#  'z_subj_trans.7335': 1.0179119142762274,
#  'z_subj_trans.7336': 1.0184829432686626,
#  'z_subj_trans.7340': 1.0047874869817908}

# %%
# Create a new model concatenating all individual models.
import kabuki
combined_model = kabuki.utils.concat_models(models)

# %% [markdown]
# ### Test the docker image: Multiple chains with progress bar
#
# Sometimes you want to know the progress of the multiple chains. To print out the progress, you need to define another function (See this [post](https://groups.google.com/g/hddm-users/c/lsmRwwB_9wY/m/0h8HLghcAwAJ) in hddm discussion group).

# %%
import sys
import time
from IPython.display import clear_output

def wait_watching_stdout(ar, dt=30):
    """
    ar: vmap output of the models being run 
    dt: number of seconds between checking output, you can make is shorter or longer.
    """

    while not ar.ready():
        stdouts = ar.stdout
        if not any(stdouts):
            continue
        # clear_output doesn't do much in terminal environments
        clear_output()
        print('-' * 30)
        print("%.3fs elapsed" % ar.elapsed)
        print("")
        for out in ar.stdout: print(out);
        sys.stdout.flush()
        time.sleep(dt)

# %%
from ipyparallel import Client
start_time = time.time()  # the start time of the processing
v = Client()[:]
jobs = v.map(run_model, range(4)) # 4 is the number of CPUs
wait_watching_stdout(jobs)
models = jobs.get()

m1_time = time.time() 
print("\nRunning 4 chains used: %f seconds." % (m1_time - start_time))
# Out:
# ------------------------------
# 210.529s elapsed
#
# running model0
# running models 0 for for exp example
#  [-----------------96%----------------  ] 484 of 500 complete in 194.7 sec
# running model1
# running models 1 for for exp example
#  [-----------------95%----------------  ] 476 of 500 complete in 194.4 sec
# running model2
# running models 2 for for exp example
#  [-----------------97%----------------  ] 485 of 500 complete in 194.6 sec
# running model3
# running models 3 for for exp example
#  [-----------------97%----------------  ] 485 of 500 complete in 194.5 sec
# Running 4 chains used: 240.572308 seconds.
