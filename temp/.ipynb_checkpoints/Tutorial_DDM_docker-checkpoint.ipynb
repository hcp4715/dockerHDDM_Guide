# %% [markdown]
# # Notebook for `HDDM_docker`
#
# Author: Hu Chuan-Peng (PhD) @Nanjing Normal University
# E-mail: hcp4715@hotmail.com
#
#
# This is a notebook for an introductary paper of this docker image, which might be titled as *HDDM_docker: A docker image for reproducible Bayesian hierarchical drift-diffusion modelling*.
#
# In this notebook, we will demostrate how to conduct HDDM analysis with docker image `hcp4715/hddm:tutorial`.

# %%
# %matplotlib inline

# General packages for system, time, etc
import os, time, csv, sys
import datetime
from datetime import date
import glob
import feather  # for compiling files

# scitnific computing and plotting
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import seaborn as sns

# HDDM related packages
import pymc as pm
import hddm
import kabuki
import arviz as az
print("The current HDDM version is: ", hddm.__version__)
print("The current PyMC version is: ", pm.__version__)
print("The current ArviZ version is: ", az.__version__)

# parallel processing related
from p_tqdm import p_map
from functools import partial
# Out:
# /opt/conda/lib/python3.8/site-packages/IPython/parallel.py:12: ShimWarning: The `IPython.parallel` package has been deprecated since IPython 4.0. You should import from ipyparallel instead.
#   warn("The `IPython.parallel` package has been deprecated since IPython 4.0. "
# The current HDDM version is:  0.8.0
# The current PyMC version is:  2.3.8
# The current ArviZ version is:  0.11.4

# %% [markdown]
# ### Import func for converting HDDM objects to `InferenceData`
#
# The scripts are stored at the `scripts` folder, which need to be added to the path temporarily.

# %%
# add `script` to the python path so that we can import the scripts
# scripts_dir = os.path.join(os.path.dirname(os.getcwd()), 'scripts')
scripts_dir = '/home/jovyan/hddm/scripts'
sys.path.append(scripts_dir)

from HDDMarviz import HDDMarviz
from plot_ppc_by_cond import plot_ppc_by_cond

# %% [markdown]
# #### Load the example data Cavanaght et al. (2011)

# %%
data_cavanagh = hddm.load_csv(os.path.join(os.path.dirname(hddm.__file__), 
                                           'examples', 
                                           'cavanagh_theta_nn.csv'))
data_cavanagh.tail()
# Out:
#       subj_idx stim     rt  response     theta  dbs conf
# 3983        13   LL  1.450       0.0 -1.237166    0   HC
# 3984        13   WL  0.711       1.0 -0.377450    0   LC
# 3985        13   WL  0.784       1.0 -0.694194    0   LC
# 3986        13   LL  2.350       0.0 -0.546536    0   HC
# 3987        13   WW  1.250       1.0  0.752388    0   HC

# %% [markdown]
# #### Define functions for parallel processing

# %%
# %%time
# M0_0: base model: simplified
def ms0(id, df=None, samples=None, burn=None, thin=1, save_name="ms0"): 
    # for HDDM models, adding this print func can prevent warnings that would occur
    #  when running parallel processing in jupyter
    print('running chain {:d} for model {}'.format(id, save_name))
    import hddm
    
    dbname = save_name + '_chain_%i.db'%id 
    mname  = save_name + '_chain_%i'%id    
    m = hddm.HDDM(df)
    m.find_starting_values()
    m.sample(samples, burn=burn, thin=thin, dbname=dbname, db='pickle') # it's neccessary to save the model data
    m.save(mname)
    
    return m

# M4: regression model (varying intercept and slope)
def ms4(id, df=None, samples=None, burn=None, thin = 1, save_name="ms4"): 
    print('running chain {:d} for model {}'.format(id, save_name))
    import hddm
    
    dbname = save_name + '_chain_%i.db'%id 
    mname  = save_name + '_chain_%i'%id   
    m = hddm.HDDMRegressor(df,
                           "v ~ C(conf, Treatment('LC'))", 
                           group_only_regressors=False,
                           keep_regressor_trace=True,
                           include=['z', 'sv', 'st', 'sz'])
    m.find_starting_values()
    m.sample(samples, burn=burn, thin=thin, dbname=dbname, db='pickle') # it's neccessary to save the model data
    m.save(mname)
    
    return m
# Out:
# CPU times: user 10 µs, sys: 0 ns, total: 10 µs
# Wall time: 16.2 µs

# %% [markdown]
# #### Define parameter for model fitting and converting

# %%
samples = 300  # number of MCMC sample; Cavanagh et al. 2011 used 30,000 and 10, 000 burn.
burn = 100     # number of burn in
nppc = 50      # number of posterior predictive, super slow
thin = 1       # thining
chains = 4     # number of chains, default is 4
test_mode = False  # Test model will only run the simplest model
savefile=True      # save file or not, only "True" is available for now.
savetag = "tmp"    # tag added to saved files.

# %%
# %%time
# If test_mode is true, we will only run the simplest model
if test_mode:
    model_func = ms0

else: 
    model_func = [ms0,  
                  ms4]
# Out:
# CPU times: user 2 µs, sys: 3 µs, total: 5 µs
# Wall time: 8.34 µs

# %% [markdown]
# #### Fit the model and convert to Inference data

# %%
models, InfData = HDDMarviz(data=data_cavanagh, 
                            model_func=model_func,
                            samples=samples, 
                            nppc=nppc, 
                            burn=burn, 
                            thin=thin, 
                            chains=chains, 
                            savefile=savefile,
                            savetag=savetag)
# Out:
# start model fitting for ms0
# running chain 0 for model ms0_tmp
#   0%|          | 0/4 [00:00<?, ?it/s]
# running chain 1 for model ms0_tmp
# running chain 2 for model ms0_tmp
# running chain 3 for model ms0_tmp
# /opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py:2215: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py:2215: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py:2215: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /opt/conda/lib/python3.8/site-packages/scipy/optimize/optimize.py:2215: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
#  ------------     33%                  ] 99 of 300 complete in 4.7 secc[-                 4%                  ] 12 of 300 complete in 0.5 sec[-                 4%                  ] 12 of 300 complete in 0.5 sec[-                 4%                  ] 12 of 300 complete in 0.5 sec[--                7%                  ] 23 of 300 complete in 1.0 sec[--                7%                  ] 23 of 300 complete in 1.0 sec[--                7%                  ] 23 of 300 complete in 1.1 sec[--                7%                  ] 23 of 300 complete in 1.0 sec[----             11%                  ] 34 of 300 complete in 1.5 sec[----             11%                  ] 34 of 300 complete in 1.6 sec[----             11%                  ] 34 of 300 complete in 1.6 sec[----             11%                  ] 34 of 300 complete in 1.6 sec[-----            14%                  ] 44 of 300 complete in 2.1 sec[-----            15%                  ] 45 of 300 complete in 2.1 sec[-----            15%                  ] 45 of 300 complete in 2.1 sec[-----            15%                  ] 45 of 300 complete in 2.1 sec[------           18%                  ] 55 of 300 complete in 2.6 sec[-------          18%                  ] 56 of 300 complete in 2.6 sec[-------          18%                  ] 56 of 300 complete in 2.6 sec[------           18%                  ] 55 of 300 complete in 2.6 sec[--------         22%                  ] 66 of 300 complete in 3.1 sec[--------         22%                  ] 67 of 300 complete in 3.1 sec[--------         22%                  ] 67 of 300 complete in 3.2 sec[--------         22%                  ] 66 of 300 complete in 3.1 sec[
-----------------64%----              ] 9 of 14 complete in 3.9 sec[-----------------64%----              ] 9 of 14 complete in 3.9 sec[-----------------64%----              ] 9 of 14 complete in 3.8 sec[-----------------64%----              ] 9 of 14 complete in 3.9 sec[-----------------71%-------           ] 10 of 14 complete in 4.5 sec[-----------------71%-------           ] 10 of 14 complete in 4.5 sec[-----------------71%-------           ] 10 of 14 complete in 4.4 sec[-----------------71%-------           ] 10 of 14 complete in 4.5 sec[-----------------78%---------         ] 11 of 14 complete in 5.1 sec[-----------------78%---------         ] 11 of 14 complete in 5.1 sec[-----------------78%---------         ] 11 of 14 complete in 5.1 sec[-----------------78%---------         ] 11 of 14 complete in 5.2 sec[-----------------85%------------      ] 12 of 14 complete in 5.9 sec[-----------------85%------------      ] 12 of 14 complete in 5.9 sec[-----------------85%------------      ] 12 of 14 complete in 5.8 sec[-----------------85%------------      ] 12 of 14 complete in 5.9 sec[-----------------92%---------------   ] 13 of 14 complete in 6.5 sec[-----------------92%---------------   ] 13 of 14 complete in 6.5 sec[-----------------92%---------------   ] 13 of 14 complete in 6.6 sec[-----------------92%---------------   ] 13 of 14 complete in 6.6 sec[-----------------100%-----------------] 14 of 14 complete in 7.1 sec[-----------------100%-----------------] 14 of 14 complete in 7.1 sec[-----------------100%-----------------] 14 of 14 complete in 7.2 sec[-----------------100%-----------------] 14 of 14 complete in 7.3 sec[------------------107%------------------] 15 of 14 complete in 7.8 sec[------------------107%------------------] 15 of 14 complete in 7.8 sec[------------------107%------------------] 15 of 14 complete in 7.9 sec[------------------107%------------------] 15 of 14 complete in 7.9 sec[-------------------114%--------------------] 16 of 14 complete in 8.4 sec[-------------------114%--------------------] 16 of 14 complete in 8.4 sec[-------------------114%--------------------] 16 of 14 complete in 8.5 sec[-------------------114%--------------------] 16 of 14 complete in 8.6 sec[---------------------121%---------------------] 17 of 14 complete in 9.1 sec[---------------------121%---------------------] 17 of 14 complete in 9.0 sec[---------------------121%---------------------] 17 of 14 complete in 9.1 sec[---------------------121%---------------------] 17 of 14 complete in 9.3 sec
#   0%|          | 0/4 [00:00<?, ?it/s]
# started to generate posterior predicitves
# started to generate posterior predicitves
# started to generate posterior predicitves
# started to generate posterior predicitves
#  [-----------------64%----              ] 9 of 14 complete in 0.5 sec[-----------------64%----              ] 9 of 14 complete in 0.5 sec[-----------------71%-------           ] 10 of 14 complete in 0.6 sec[-----------------71%-------           ] 10 of 14 complete in 0.6 sec[-----------------100%-----------------] 14 of 14 complete in 1.0 sec[-----------------100%-----------------] 14 of 14 complete in 1.0 sec[-----------------100%-----------------] 14 of 14 complete in 1.0 sec[-------------------114%--------------------] 16 of 14 complete in 1.1 sec[------------------107%------------------] 15 of 14 complete in 1.0 sec[---------------------121%---------------------] 17 of 14 complete in 1.1 sec[---------------------121%---------------------] 17 of 14 complete in 1.2 secstart model fitting for ms4
#   0%|          | 0/4 [00:00<?, ?it/s]
# running chain 0 for model ms4_tmp
# running chain 2 for model ms4_tmpAdding these covariates:
#
# ['v_Intercept', "v_C(conf, Treatment('LC'))[T.HC]"]
# running chain 1 for model ms4_tmp
#  [-----------------99%----------------- ] 299 of 300 complete in 328.6 secWARNING: Custom link functions will not be loaded.
#  [-----------------99%----------------- ] 297 of 300 complete in 328.9 sec[-----------------100%-----------------] 300 of 300 complete in 329.8 sec[-----------------99%----------------- ] 298 of 300 complete in 329.9 sec[-----------------99%----------------- ] 299 of 300 complete in 330.9 sec[-----------------100%-----------------] 301 of 300 complete in 330.9 secWARNING: Will not save custom link functions.
# WARNING: Custom link functions will not be loaded.
#  [-----------------100%-----------------] 300 of 300 complete in 332.0 sec[-----------------100%-----------------] 301 of 300 complete in 333.0 secWARNING: Will not save custom link functions.
# WARNING: Custom link functions will not be loaded.
#   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.
# WARNING: Custom link functions will not be loaded.
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
# WARNING: Custom link functions will not be loaded.
# started to generate posterior predicitves
# started to generate posterior predicitves
# started to generate posterior predicitves
# started to generate posterior predicitves
#  [----------       28%                  ] 4 of 14 complete in 54.3 sec[----------       28%                  ] 4 of 14 complete in 54.2 sec[----------       28%                  ] 4 of 14 complete in 54.2 sec[----------       28%                  ] 4 of 14 complete in 55.1 sec[-------------    35%                  ] 5 of 14 complete in 110.6 sec[-------------    35%                  ] 5 of 14 complete in 110.8 sec[-------------    35%                  ] 5 of 14 complete in 111.2 sec[-------------    35%                  ] 5 of 14 complete in 112.3 sec[---------------- 42%                  ] 6 of 14 complete in 163.4 sec[---------------- 42%                  ] 6 of 14 complete in 163.7 sec[---------------- 42%                  ] 6 of 14 complete in 163.9 sec[---------------- 42%                  ] 6 of 14 complete in 166.4 sec[-----------------50%                  ] 7 of 14 complete in 211.5 sec[-----------------50%                  ] 7 of 14 complete in 211.8 sec[-----------------50%                  ] 7 of 14 complete in 212.8 sec[-----------------50%                  ] 7 of 14 complete in 214.6 sec[-----------------57%-                 ] 8 of 14 complete in 262.3 sec[-----------------57%-                 ] 8 of 14 complete in 262.9 sec[-----------------57%-                 ] 8 of 14 complete in 263.2 sec[-----------------57%-                 ] 8 of 14 complete in 265.1 sec[-----------------64%----              ] 9 of 14 complete in 318.1 sec[-----------------64%----              ] 9 of 14 complete in 318.6 sec[-----------------64%----              ] 9 of 14 complete in 318.8 sec[-----------------64%----              ] 9 of 14 complete in 320.6 sec[-----------------71%-------           ] 10 of 14 complete in 372.0 sec[-----------------71%-------           ] 10 of 14 complete in 373.4 sec[-----------------71%-------           ] 10 of 14 complete in 373.5 sec[-----------------71%-------           ] 10 of 14 complete in 374.5 sec[-----------------78%---------         ] 11 of 14 complete in 427.1 sec[-----------------78%---------         ] 11 of 14 complete in 428.0 sec[-----------------78%---------         ] 11 of 14 complete in 428.2 sec[-----------------78%---------         ] 11 of 14 complete in 428.5 sec[-----------------85%------------      ] 12 of 14 complete in 483.0 sec[-----------------85%------------      ] 12 of 14 complete in 483.
in 124.4 sec[-----------------78%---------         ] 11 of 14 complete in 140.0 sec[-----------------78%---------         ] 11 of 14 complete in 140.1 sec[-----------------78%---------         ] 11 of 14 complete in 140.7 sec[-----------------78%---------         ] 11 of 14 complete in 142.1 sec[-----------------85%------------      ] 12 of 14 complete in 157.4 sec[-----------------85%------------      ] 12 of 14 complete in 158.2 sec[-----------------85%------------      ] 12 of 14 complete in 158.3 sec[-----------------85%------------      ] 12 of 14 complete in 159.2 sec[-----------------92%---------------   ] 13 of 14 complete in 170.4 sec[-----------------92%---------------   ] 13 of 14 complete in 170.9 sec[-----------------92%---------------   ] 13 of 14 complete in 171.3 sec[-----------------92%---------------   ] 13 of 14 complete in 171.7 sec[-----------------100%-----------------] 14 of 14 complete in 188.6 sec[-----------------100%-----------------] 14 of 14 complete in 189.0 sec[-----------------100%-----------------] 14 of 14 complete in 190.1 sec[-----------------100%-----------------] 14 of 14 complete in 190.3 sec[------------------107%------------------] 15 of 14 complete in 207.0 sec[------------------107%------------------] 15 of 14 complete in 207.3 sec[------------------107%------------------] 15 of 14 complete in 207.9 sec[------------------107%------------------] 15 of 14 complete in 208.3 sec[-------------------114%--------------------] 16 of 14 complete in 222.5 sec[-------------------114%--------------------] 16 of 14 complete in 223.5 sec[-------------------114%--------------------] 16 of 14 complete in 224.0 sec[-------------------114%--------------------] 16 of 14 complete in 224.0 sec[---------------------121%---------------------] 17 of 14 complete in 238.6 sec[---------------------121%---------------------] 17 of 14 complete in 239.8 sec[---------------------121%---------------------] 17 of 14 complete in 240.2 sec[---------------------121%---------------------] 17 of 14 complete in 240.5 sec

# %% [markdown]
# ## Bayesian modelling with `ArviZ`

# %% [markdown]
# ### Model diagnosis

# %% [markdown]
# #### Visual inspection

# %%
InfData
# Out:
# {'ms0': Inference data with groups:
#  	> posterior
#  	> posterior_predictive
#  	> log_likelihood
#  	> observed_data,
#  'ms4': Inference data with groups:
#  	> posterior
#  	> posterior_predictive
#  	> log_likelihood
#  	> observed_data}

# %%
az.plot_trace(InfData['ms0'])
# Out:
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'a'}>],
#        [<AxesSubplot:title={'center':'a_std'}>,
#         <AxesSubplot:title={'center':'a_std'}>],
#        [<AxesSubplot:title={'center':'a_subj.0'}>,
#         <AxesSubplot:title={'center':'a_subj.0'}>],
#        [<AxesSubplot:title={'center':'a_subj.1'}>,
#         <AxesSubplot:title={'center':'a_subj.1'}>],
#        [<AxesSubplot:title={'center':'a_subj.2'}>,
#         <AxesSubplot:title={'center':'a_subj.2'}>],
#        [<AxesSubplot:title={'center':'a_subj.3'}>,
#         <AxesSubplot:title={'center':'a_subj.3'}>],
#        [<AxesSubplot:title={'center':'a_subj.4'}>,
#         <AxesSubplot:title={'center':'a_subj.4'}>],
#        [<AxesSubplot:title={'center':'a_subj.5'}>,
#         <AxesSubplot:title={'center':'a_subj.5'}>],
#        [<AxesSubplot:title={'center':'a_subj.6'}>,
#         <AxesSubplot:title={'center':'a_subj.6'}>],
#        [<AxesSubplot:title={'center':'a_subj.7'}>,
#         <AxesSubplot:title={'center':'a_subj.7'}>],
#        [<AxesSubplot:title={'center':'a_subj.8'}>,
#         <AxesSubplot:title={'center':'a_subj.8'}>],
#        [<AxesSubplot:title={'center':'a_subj.9'}>,
#         <AxesSubplot:title={'center':'a_subj.9'}>],
#        [<AxesSubplot:title={'center':'a_subj.10'}>,
#         <AxesSubplot:title={'center':'a_subj.10'}>],
#        [<AxesSubplot:title={'center':'a_subj.11'}>,
#         <AxesSubplot:title={'center':'a_subj.11'}>],
#        [<AxesSubplot:title={'center':'a_subj.12'}>,
#         <AxesSubplot:title={'center':'a_subj.12'}>],
#        [<AxesSubplot:title={'center':'a_subj.13'}>,
#         <AxesSubplot:title={'center':'a_subj.13'}>],
#        [<AxesSubplot:title={'center':'v'}>,
#         <AxesSubplot:title={'center':'v'}>],
#        [<AxesSubplot:title={'center':'v_std'}>,
#         <AxesSubplot:title={'center':'v_std'}>],
#        [<AxesSubplot:title={'center':'v_subj.0'}>,
#         <AxesSubplot:title={'center':'v_subj.0'}>],
#        [<AxesSubplot:title={'center':'v_subj.1'}>,
#         <AxesSubplot:title={'center':'v_subj.1'}>]], dtype=object)

# %%
# using regex to select var_names that start with "a" 
#  and do not contain either "subj" or "std"
az.plot_trace(InfData['ms4'], var_names=("^a(?!.*(subj|std))"), filter_vars='regex')
# Out:
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'a'}>]], dtype=object)

# %% [markdown]
# #### Using `az.summary()` to check $\hat{R}$ and ESS

# %%
ms0_summary = az.summary(InfData['ms0'])
ms0_summary.sort_values('r_hat')
# Out:
#             mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# v_subj.5   0.497  0.072   0.359    0.616      0.003    0.002     742.0
# v_subj.8   0.495  0.061   0.381    0.610      0.002    0.002     648.0
# v_subj.7   0.030  0.066  -0.089    0.158      0.003    0.002     658.0
# v_subj.11  0.592  0.060   0.491    0.713      0.002    0.002     639.0
# v_subj.12  0.610  0.072   0.473    0.734      0.003    0.002     672.0
# v_subj.4   0.950  0.090   0.770    1.101      0.004    0.003     534.0
# v_subj.3   0.166  0.061   0.040    0.268      0.002    0.002     648.0
# v_subj.13  0.218  0.058   0.117    0.330      0.002    0.002     691.0
# v_subj.1   0.666  0.062   0.541    0.773      0.002    0.002     704.0
# v_subj.0   0.129  0.055   0.035    0.241      0.002    0.001     800.0
# v_std      0.290  0.071   0.173    0.419      0.004    0.003     408.0
# v          0.444  0.084   0.288    0.606      0.003    0.002     708.0
# v_subj.9   0.230  0.067   0.112    0.357      0.002    0.002     885.0
# a_subj.12  1.882  0.059   1.766    1.985      0.003    0.002     492.0
# t_subj.0   0.551  0.028   0.500    0.603      0.001    0.001     552.0
# t_subj.1   0.399  0.016   0.370    0.426      0.001    0.001     386.0
# a_subj.7   1.796  0.052   1.693    1.888      0.002    0.002     497.0
# t_subj.3   0.556  0.031   0.492    0.610      0.001    0.001     450.0
# t_subj.7   0.598  0.014   0.574    0.622      0.001    0.000     482.0
# t_subj.9   0.368  0.018   0.335    0.403      0.001    0.001     454.0
# t_std      0.121  0.030   0.076    0.179      0.001    0.001     488.0
# v_subj.10  0.572  0.064   0.447    0.682      0.002    0.002     764.0
# t          0.491  0.033   0.435    0.559      0.001    0.001     706.0
# t_subj.2   0.495  0.009   0.478    0.511      0.000    0.000     494.0
# t_subj.4   0.346  0.009   0.331    0.363      0.000    0.000     340.0
# t_subj.5   0.354  0.011   0.335    0.375      0.001    0.000     411.0
# t_subj.6   0.424  0.010   0.403    0.442      0.000    0.000     491.0
# t_subj.8   0.542  0.025   0.505    0.601      0.001    0.001     394.0
# t_subj.10  0.657  0.020   0.615    0.692      0.001    0.001     448.0
# a          1.983  0.099   1.796    2.160      0.004    0.003     622.0
# t_subj.12  0.401  0.013   0.376    0.423      0.001    0.000     478.0
# a_std      0.347  0.090   0.210    0.510      0.005    0.004     351.0
# a_subj.0   2.201  0.061   2.091    2.308      0.003    0.002     538.0
# a_subj.1   2.114  0.064   1.996    2.229      0.003    0.002     372.0
# a_subj.2   1.559  0.047   1.475    1.652      0.002    0.002     487.0
# a_subj.3   2.159  0.069   2.046    2.299      0.003    0.002     424.0
# v_subj.6   0.460  0.074   0.320    0.599      0.003    0.002     750.0
# a_subj.5   1.760  0.050   1.666    1.848      0.002    0.002     425.0
# a_subj.8   2.148  0.065   2.036    2.278      0.003    0.002     398.0
# a_subj.9   2.130  0.066   2.021    2.274      0.003    0.002     509.0
# a_subj.10  2.090  0.064   1.967    2.201      0.003    0.002     416.0
# a_subj.11  2.438  0.083   2.282    2.588      0.005    0.003     310.0
# v_subj.2   0.562  0.085   0.406    0.706      0.003    0.002     679.0
# a_subj.6   1.595  0.046   1.496    1.672      0.002    0.002     427.0
# t_subj.13  0.527  0.026   0.480    0.576      0.001    0.001     398.0
# a_subj.4   1.481  0.047   1.398    1.566      0.003    0.002     269.0
# a_subj.13  2.274  0.067   2.155    2.407      0.004    0.002     360.0
# t_subj.11  0.618  0.024   0.575    0.663      0.001    0.001     301.0
#
#            ess_tail  r_hat
# v_subj.5      474.0   1.00
# v_subj.8      569.0   1.00
# v_subj.7      561.0   1.00
# v_subj.11     550.0   1.00
# v_subj.12     605.0   1.00
# v_subj.4      588.0   1.00
# v_subj.3      469.0   1.00
# v_subj.13     595.0   1.00
# v_subj.1      533.0   1.00
# v_subj.0      512.0   1.00
# v_std         359.0   1.00
# v             593.0   1.00
# v_subj.9      733.0   1.00
# a_subj.12     493.0   1.00
# t_subj.0      526.0   1.00
# t_subj.1      559.0   1.00
# a_subj.7      565.0   1.00
# t_subj.3      492.0   1.00
# t_subj.7      493.0   1.00
# t_subj.9      382.0   1.00
# t_std         392.0   1.00
# v_subj.10     592.0   1.00
# t             524.0   1.01
# t_subj.2      549.0   1.01
# t_subj.4      399.0   1.01
# t_subj.5      488.0   1.01
# t_subj.6      412.0   1.01
# t_subj.8      433.0   1.01
# t_subj.10     380.0   1.01
# a             366.0   1.01
# t_subj.12     515.0   1.01
# a_std         337.0   1.01
# a_subj.0      593.0   1.01
# a_subj.1      359.0   1.01
# a_subj.2      574.0   1.01
# a_subj.3      541.0   1.01
# v_subj.6      608.0   1.01
# a_subj.5      514.0   1.01
# a_subj.8      559.0   1.01
# a_subj.9      616.0   1.01
# a_subj.10     343.0   1.01
# a_subj.11     402.0   1.01
# v_subj.2      586.0   1.01
# a_subj.6      402.0   1.01
# t_subj.13     388.0   1.01
# a_subj.4      429.0   1.02
# a_subj.13     490.0   1.02
# t_subj.11     515.0   1.02

# %%
ms4_summary = az.summary(InfData['ms4'])
ms4_summary.sort_values('r_hat')
# Out:
#                                        mean     sd  hdi_3%  hdi_97%  \
# a_std                                 0.383  0.085   0.252    0.555
# t_std                                 0.111  0.028   0.065    0.163
# a                                     1.841  0.105   1.636    2.022
# v_Intercept_subj.9                    0.547  0.097   0.368    0.722
# a_subj.12                             1.676  0.070   1.549    1.806
# ...                                     ...    ...     ...      ...
# z_subj_trans.4                        0.050  0.062  -0.050    0.178
# z_subj_trans.10                       0.103  0.067   0.001    0.227
# z_subj_trans.1                        0.064  0.059  -0.036    0.192
# v_C(conf, Treatment('LC'))[T.HC]_std  0.147  0.062   0.034    0.267
# z_trans                               0.046  0.037  -0.013    0.119
#
#                                       mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# a_std                                     0.005    0.003     338.0     516.0
# t_std                                     0.001    0.001     550.0     499.0
# a                                         0.005    0.004     413.0     531.0
# v_Intercept_subj.9                        0.006    0.004     274.0     362.0
# a_subj.12                                 0.004    0.003     262.0     302.0
# ...                                         ...      ...       ...       ...
# z_subj_trans.4                            0.012    0.008      26.0     264.0
# z_subj_trans.10                           0.013    0.009      22.0     117.0
# z_subj_trans.1                            0.012    0.009      22.0     253.0
# v_C(conf, Treatment('LC'))[T.HC]_std      0.012    0.009      23.0      35.0
# z_trans                                   0.010    0.007      15.0      98.0
#
#                                       r_hat
# a_std                                  1.00
# t_std                                  1.00
# a                                      1.01
# v_Intercept_subj.9                     1.01
# a_subj.12                              1.01
# ...                                     ...
# z_subj_trans.4                         1.12
# z_subj_trans.10                        1.14
# z_subj_trans.1                         1.14
# v_C(conf, Treatment('LC'))[T.HC]_std   1.16
# z_trans                                1.22
#
# [83 rows x 9 columns]

# %% [markdown]
# ### Model comparison and selection

# %% [markdown]
# #### DIC
#
# Here we record the DIC of each model in the models and sort by DIC.

# %%
# %%time

tmp_dic = []
indx_name = []
for m_key, model in models.items():
    m_tmp = kabuki.utils.concat_models(model)
    tmp_dic.append(m_tmp.dic)
    indx_name.append(m_key)
    
comp_dic = pd.DataFrame(tmp_dic, index=indx_name, columns=['dic'])
comp_dic = comp_dic.sort_values(by=['dic'])
comp_dic = comp_dic.reset_index()
comp_dic.rename(columns={'index':'rank'}, inplace=True)
comp_dic
# Out:
# WARNING: Custom link functions will not be loaded.
# CPU times: user 2.94 s, sys: 1.74 ms, total: 2.94 s
# Wall time: 2.93 s
#   rank           dic
# 0  ms4  10661.220706
# 1  ms0  10971.674846

# %% [markdown]
# #### PSIS-LOO-CV

# %%
comp_loo = az.compare(InfData, ic='loo')
comp_loo
# Out:
#      rank          loo        p_loo        d_loo    weight           se  \
# ms4     0 -6171.947803   768.547165     0.000000  0.797389   338.180711
# ms0     1 -9127.846990  3611.073902  2955.899187  0.202611  1151.975702
#
#              dse  warning loo_scale
# ms4     0.000000     True       log
# ms0  1176.138058     True       log

# %% [markdown]
# ####  WAIC

# %%
comp_waic = az.compare(InfData, ic='waic')
comp_waic
# Out:
#      rank          waic        p_waic        d_waic    weight            se  \
# ms4     0 -10849.001794   5445.601156      0.000000  0.794732   2749.286816
# ms0     1 -36936.149091  31419.376004  26087.147297  0.205268  11731.226740
#
#               dse  warning waic_scale
# ms4      0.000000     True        log
# ms0  12015.499794     True        log

# %% [markdown]
# #### Posterior predictive check

# %%
az.plot_ppc(InfData['ms0'])
# Out:
# array([<AxesSubplot:xlabel='rt / rt'>,
#        <AxesSubplot:xlabel='response / response'>], dtype=object)

# %%
az.plot_ppc(InfData['ms4'])
# Out:
# array([<AxesSubplot:xlabel='rt / rt'>,
#        <AxesSubplot:xlabel='response / response'>], dtype=object)

# %%
plot_ppc_by_cond(data = InfData['ms4'],
                 or_d = data_cavanagh,
                 subjs = [3],
                 conds = ['conf','dbs'],
                 colors = ['r', 'k', 'b'],
                 num_pp_samples=100,
                 random_seed = 7,
                 alpha = 0.2,
                 grid = [2,2],
                 var_names=['rt'])
# Out:
# [3, 'HC', 1]
# [3, 'LC', 1]
# [3, 'LC', 0]
# [3, 'HC', 0]
# array([[<AxesSubplot:xlabel='rt / rt\nsubj_3, conf_HC, dbs_1'>,
#         <AxesSubplot:xlabel='rt / rt\nsubj_3, conf_LC, dbs_1'>],
#        [<AxesSubplot:xlabel='rt / rt\nsubj_3, conf_LC, dbs_0'>,
#         <AxesSubplot:xlabel='rt / rt\nsubj_3, conf_HC, dbs_0'>]],
#       dtype=object)

# %%
plot_ppc_by_cond(data = InfData['ms0'],
                 or_d = data_cavanagh,
                 subjs = [3],
                 conds = ['conf','dbs'],
                 colors = ['r', 'k', 'b'],
                 num_pp_samples=100,
                 random_seed = 7,
                 alpha = 0.2,
                 grid = [2,2],
                 var_names=['rt'])
# Out:
# [3, 'HC', 1]
# [3, 'LC', 1]
# [3, 'LC', 0]
# [3, 'HC', 0]
# array([[<AxesSubplot:xlabel='rt / rt\nsubj_3, conf_HC, dbs_1'>,
#         <AxesSubplot:xlabel='rt / rt\nsubj_3, conf_LC, dbs_1'>],
#        [<AxesSubplot:xlabel='rt / rt\nsubj_3, conf_LC, dbs_0'>,
#         <AxesSubplot:xlabel='rt / rt\nsubj_3, conf_HC, dbs_0'>]],
#       dtype=object)

# %% [markdown]
# ## Statistical Inference

# %%
# using regex to select var_names that start with "a_theta" and do not contain either "subj" or "std"
az.plot_posterior(InfData['ms4'], 
                  var_names=("^v_(?!.*(subj|std))"), 
                  filter_vars='regex',
                  grid = [2, 2], 
                  kind = 'hist',
                  hdi_prob = 0.95,
                  rope = [-0.2, 0.2], # assume this is our ROPE
                  rope_color = 'r')
# Out:
# array([[<AxesSubplot:title={'center':'v_Intercept'}>,
#         <AxesSubplot:title={'center':"v_C(conf, Treatment('LC'))[T.HC]"}>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)
