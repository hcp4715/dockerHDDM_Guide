# %% [markdown]
# ## Dissect the example of Stimulus Coding with HDDMRegression
#
# On the HDDM website, there is a tutorial on [Stimulus Coding with HDDMRegression](http://ski.clps.brown.edu/hddm_docs/tutorial_regression_stimcoding.html), which provides a good example to understand how the regression model works.
#
# Here we will reproduce everything in the tutorial, with more details being exhibited.

# %%
# check which python is in use.
import sys
print('Notebook is running:', sys.executable)

# further check your python version
from platform import python_version

print('The current Python version is', python_version())

# If you are sure that conda is installed, also check the package that install
#!conda list  # list the conda

import hddm, IPython, kabuki, pymc
import numpy as np
import pandas as pd
import seaborn as sns
print('The current HDDM version is', hddm.__version__) # 0.8.0
print('The current Kabuki version is', kabuki.__version__) # 0.6.3
print('The current PyMC version is', pymc.__version__) # 2.3.8

# Warning:`IPython.parallel` package has been deprecated since IPython 4.0. 
print('The current IPython version is', IPython.__version__) 

print('The current Numpy version is', np.__version__) 

print('The current Pandas version is', pd.__version__)

print('The current seaborn version is', sns.__version__)
# Out:
# Notebook is running: /opt/conda/bin/python
# The current Python version is 3.7.10
# The current HDDM version is 0.8.0
# The current Kabuki version is 0.6.3
# The current PyMC version is 2.3.8
# The current IPython version is 7.15.0
# The current Numpy version is 1.19.1
# The current Pandas version is 1.0.5
# The current seaborn version is 0.11.0
# /opt/conda/lib/python3.7/site-packages/IPython/parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated since IPython 4.0. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)

# %%
# %matplotlib inline

# Preparation
import os, time, csv
from datetime import date
import random

import kabuki, hddm
from patsy import dmatrix

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Creating simulated data for the experiment
#
# First, let's simulate the data:

# %%
# set number of subjects and number of trials per level for the simulated experiment
n_subjects = 30
trials_per_level = 100

# Next, set up parameters of the DDM for three levels and the first stimulus. 
level1a = {'v':.3, 'a':2, 't':.3, 'sv':0, 'z':.5, 'sz':0, 'st':0}
level2a = {'v':.4, 'a':2, 't':.3, 'sv':0, 'z':.6, 'sz':0, 'st':0}
level3a = {'v':.5, 'a':2, 't':.3, 'sv':0, 'z':.7, 'sz':0, 'st':0}

# Next, set up parameters for the second stimulus, where `v` is the different as for the first stimulus. 
# and `z(stimulus_b) = 1 - z(stimulus_a)`. 
level1b = {'v':.3, 'a':2, 't':.3,'sv': 0, 'z':.5, 'sz': 0, 'st': 0}
level2b = {'v':.4, 'a':2, 't':.3,'sv': 0, 'z':.4, 'sz': 0, 'st': 0}
level3b = {'v':.5, 'a':2, 't':.3,'sv': 0, 'z':.3, 'sz': 0, 'st': 0}

random.seed(123)
np.random.seed(123)
data_a, params_a = hddm.generate.gen_rand_data({'level1': level1a,
                                                'level2': level2a,
                                                'level3': level3a},
                                              size=trials_per_level,
                                              subjs=n_subjects)

data_b, params_b = hddm.generate.gen_rand_data({'level1': level1b,
                                                'level2': level2b,
                                                'level3': level3b},
                                              size=trials_per_level,
                                              subjs=n_subjects)

# combine the data from two conditions
data_a['stimulus'] = pd.Series(np.ones((len(data_a))), index=data_a.index)   # a = left
data_b['stimulus'] = pd.Series(np.ones((len(data_b)))*2, index=data_a.index) # b = right
mydata = data_a.append(data_b,ignore_index=True)

# %% [markdown]
# Now we also check how this data looks like.

# %%
mydata.head()
# Out:
#          rt  response  subj_idx condition  stimulus
# 0  1.079013       0.0         0    level1       1.0
# 1  1.100509       0.0         0    level1       1.0
# 2  0.384129       0.0         0    level1       1.0
# 3  0.531129       0.0         0    level1       1.0
# 4  0.444750       0.0         0    level1       1.0

# %% [markdown]
# We can also check how many trial per condition/response. As wrote in the tutorial, the `response` is "accuracy coded", which means `0` represents wrong response and `1` represents correct response. The `stimulus` column is coded by `1` and `2`, which means upper and lower boundary, respectively.

# %%
# check the number of trials for accurate and wrong responses for each level and stimulus
mydata.groupby(['subj_idx', 'condition', 'stimulus', 'response']).size()
# Out:
# subj_idx  condition  stimulus  response
# 0         level1     1.0       0.0         71
#                                1.0         29
#                      2.0       0.0         19
#                                1.0         81
#           level2     1.0       0.0         56
#                                            ..
# 29        level2     2.0       1.0         80
#           level3     1.0       0.0         10
#                                1.0         90
#                      2.0       0.0         25
#                                1.0         75
# Length: 360, dtype: int64

# %% [markdown]
# Finally, to have a better sense of the data, we can visualize the data. (note, here I didn't use the two-step approach usually used in real data analysis, so the SE is very narrow).
#
# As we can see from the plot, as the `z` increased for the stimulus that coded by `1` (from level 1 to level 3), the accuracy is because higher and and RTs becomes shorter. This pattern confirmed that stimulus coded by `1` is the upper boundary of DDM.

# %%
## plot the RT and Accuracy

# wide-to-long format
df_plot = pd.melt(mydata, 
                  id_vars=['subj_idx', 'condition','stimulus'], 
                  value_vars=['rt', 'response'],
                  var_name='datatype')
# df_plot.head()

# way 1: 
# stim_ord = df_plot.stimulus.unique()
# g = sns.FacetGrid(df_plot, col="datatype", 
#                  sharex=False,
#                   sharey=False,
#                  height=4)
# g.map(sns.barplot, "condition", "value",'stimulus', hue_order=np.unique(df_plot["stimulus"]))

# Way 2: 
g = sns.catplot(data=df_plot, x='condition', y='value', hue='stimulus', 
                col='datatype', kind='bar',
                sharex=True, sharey=False)

# %% [markdown]
# To compare the parameter recovered from the model and the parameters that generated the simulated data, we create a dataframe to store the parameter that generated the simulated data first (i.e., ground truth).

# %%
# Write a short function to transform the params_a into a dataframe for later use.
# params_a is a dict of lists of dicts

# type(params_a)               # dict
# type(params_a['level1'])     # list
# type(params_a['level1'][1])  # dict

# rows list initialization 
cols = ['condition', 'subj_idx', 'params', 'value']
row = []
df_params_a = pd.DataFrame([], columns = cols)
#

for level in params_a.keys(): 
    data_row = params_a[level]

    for subj, data in enumerate(data_row):

        for key, value in data.items():
            row = [[level, subj, key, value]]
            data = pd.DataFrame(row, columns=cols)
            df_params_a = df_params_a.append(data, ignore_index=True)
            

# long to wide
df_params_a = df_params_a.pivot_table(index = ['condition','subj_idx'], columns =['params'], 
                        values =['value']).reset_index() 

# rename columns
col_ind = ['condition','subj_idx', 'a_pop', 'st_pop','sv_pop', 'sz_pop', 't_pop', 'v_pop', 'z_pop']
df_params_a.columns = col_ind

df_params_a['StimType'] = 'left' # set stimulus 1 as left, upper boundary

df_params_a.head()

cols = ['condition', 'subj_idx', 'params', 'value']
row = []
df_params_b = pd.DataFrame([], columns = cols)
#

for level in params_b.keys(): 
    data_row = params_b[level]

    for subj, data in enumerate(data_row):

        for key, value in data.items():
            row = [[level, subj, key, value]]
            data = pd.DataFrame(row, columns=cols)
            df_params_b = df_params_b.append(data, ignore_index=True)
            

df_params_b = df_params_b.pivot_table(index = ['condition','subj_idx'], columns =['params'], 
                        values =['value']).reset_index() 

col_ind = ['condition','subj_idx', 'a_pop', 'st_pop','sv_pop', 'sz_pop', 't_pop', 'v_pop', 'z_pop']
df_params_b.columns = col_ind

df_params_b['StimType'] = 'right' # set stimulus 2 as right, lower boudnary

df_params_b.head()

df_params = pd.concat([df_params_a, df_params_b])
df_params.head()
# Out:
#   condition  subj_idx     a_pop    st_pop    sv_pop    sz_pop     t_pop  \
# 0    level1         0  2.099735  0.149139  0.165144  0.126594  0.328298
# 1    level1         1  2.031158  0.126082  0.075203  0.092958  0.285795
# 2    level1         2  1.922423  0.065015  0.010147  0.047277  0.417806
# 3    level1         3  1.972896  0.050523  0.072614  0.074176  0.360417
# 4    level1         4  1.898836  0.106391  0.101162  0.101349  0.384433
#
#       v_pop     z_pop StimType
# 0  0.191437  0.257332     left
# 1  0.236110  0.506964     left
# 2  0.433745  0.457832     left
# 3  0.322253  0.599803     left
# 4  0.222342  0.712582     left

# %% [markdown]
# ### Dissect complex of regression
#
# Here we will show the details of the `link_func` to understand the regression

# %%
# # below is the original link function
# def z_link_func(x, data=mydata):
#     stim = (np.asarray(dmatrix('0 + C(s, [[1], [-1]])',
#                                {'s': data.stimulus.ix[x.index]}))
#            )
#     return 1/(1 + np.exp(-(x * stim)))

# Below is the updated version of link function for recent version
# exactly the same function but changed for updated version of pandas
def z_link_func(x, data=mydata):
    stim = (dmatrix('0 + C(s, [[1], [-1]])',
                    {'s':data.stimulus.loc[x.index]}, # original .ix is deprecated.
                    return_type="dataframe"
                    )
            )
    return 1/(1+np.exp(-np.multiply(x.to_frame(), stim)))
#     return 1/(1+np.exp(-(x * stim)))

# %% [markdown]
# Let's have a look at the inside of the link function
#
# `stim = (dmatrix('0 + C(s, [[1], [-1])',
#                  {'s': data.stimulus.loc[x.index]},
#                  return_type="dataframe")
#          )`
#
# `stim` is an array derived from `dmatrix`, which is a function of `patsy`. So, we can check the syntax of `dmatrix` from `patsy`'s website.
#
# `dmatrix("C(variable_column, contrast)", data)` is a built-in **coding** scheme of `patsy`. In the `stim`'s formula, we used a custom contrast `[[1], [-1]]` to code our categorical variables `variable_column`, i.e., `s`, which is the column `stimulus` of our simulated data but indexed by `x`. More details about coding scheme of `dmatrix`, please see [here](https://patsy.readthedocs.io/en/latest/categorical-coding.html)
#
# Let's take an example, using the data from `patsy` but with our customized contrast `[[1], [-1]]`:

# %%
from patsy import dmatrix, demo_data

data = demo_data("a", nlevels=2)
data
# Out:
# {'a': ['a1', 'a2', 'a1', 'a2', 'a1', 'a2']}

# %%
dmatrix("C(a, [[1], [-1]])", data, return_type="dataframe")
# Out:
#    Intercept  C(a, [[1], [-1]])[custom0]
# 0        1.0                         1.0
# 1        1.0                        -1.0
# 2        1.0                         1.0
# 3        1.0                        -1.0
# 4        1.0                         1.0
# 5        1.0                        -1.0

# %%
dmatrix("0 + C(a, [[1], [-1]])", data, return_type="dataframe")
# Out:
#    C(a, [[1], [-1]])[custom0]
# 0                         1.0
# 1                        -1.0
# 2                         1.0
# 3                        -1.0
# 4                         1.0
# 5                        -1.0

# %% [markdown]
# Now, we can see that the `stim` part in the `z_link_func` corresponds to the sentence `... “stim”, which is 1 for all stimulus A trials and -1 for stimulus B trials` in the tutorial.
#
# Note this is the difference between `HDDMStimCoding` and doing stimulus coding with `HDDMRegression` in this tutorial: the input data, `mydata`, do not have column called `stim`. This column is defined inside the `z_link_func`. But as we can see below, we twist a bit based on this tutorial and create a column call `stim` too.
#
# But now, let's have a look how this contrast define here code `mydata`:

# %%
# recode the stimulus column to `stim`
tmp = dmatrix("0 + C(stimulus, [[1], [-1]])", mydata, return_type="dataframe")

# add this to mydata, but using a tmp variable.
tmp2 = mydata
tmp2['coding'] = tmp["C(stimulus, [[1], [-1]])[custom0]"].copy()
tmp2.groupby(['subj_idx', 'condition', 'stimulus', 'coding']).size()
# Out:
# subj_idx  condition  stimulus  coding
# 0         level1     1.0        1.0      100
#                      2.0       -1.0      100
#           level2     1.0        1.0      100
#                      2.0       -1.0      100
#           level3     1.0        1.0      100
#                                         ...
# 29        level1     2.0       -1.0      100
#           level2     1.0        1.0      100
#                      2.0       -1.0      100
#           level3     1.0        1.0      100
#                      2.0       -1.0      100
# Length: 180, dtype: int64

# %% [markdown]
# Now, we can see clearly that, using the `stim` formula in the `link_func`, stimulus `1` was redefined as `1`, the upper boundary, and stimulus `2` was redefined as `-1`, the lower boundary.

# %% [markdown]
# Let's turn to the next part of the `link_func`: `np.multiply(x.to_frame(), stim))` or `(x * stim)`. This part corresponds to `... dot-multiplying the regression output “x” (which is an array) with equally sized array “stim” `. `x` here is the output of **regression**. You may wonder, which **regression**? Wait a moment.
#
# The outcome of the `z_link_func`, `1/(1+np.exp(-np.multiply(x.to_frame(), stim)))`, is corresponding to the sentence `Therefore we use a link-function, here the inverse logit 1/(1+exp(-x)), which transforms values between plus and minus infinity into values ranging from (just above) 0 to (nearly) 1.`

# %% [markdown]
# Before explaining how the link function works, let's understand the function of link function by brutal force. We remove different part of the link_func and check how the change affect the parameter recovery. For this purpose, we build five models:
#
# * M1: the original model in the tutorial;
# * M2: replace the formula of `stim` in the link function, manually add a column for `stim_col`;
# * M3: do not use inverse logit transform of `z`;
# * M4: do not use the `stim` transform;
# * M5: do not use link function at all
#
# We then compare the `z` from these four models. Comparing M1 and M2, we can confirm the function of `stim`; comparing M1 and M3, we can check the function of `1/(1+exp(-x))`; Compare M1 and M4, we can check the function of `stim`.

# %%
# M1: 
z_reg1 = {'model': 'z ~ 1 + C(condition)', 'link_func': z_link_func}
v_reg1 = {'model': 'v ~ 1 + C(condition)', 'link_func': lambda x: x}
reg_descr1 = [z_reg1, v_reg1]
m_reg1 = hddm.HDDMRegressor(mydata, reg_descr1, include='z')
m_reg1.sample(7000, burn=2000)
m_reg1.print_stats()
# Out:
# Adding these covariates:
# ['z_Intercept', 'z_C(condition)[T.level2]', 'z_C(condition)[T.level3]']
# Adding these covariates:
# ['v_Intercept', 'v_C(condition)[T.level2]', 'v_C(condition)[T.level3]']
#  [-                 2%                  ] 186 of 7000 complete in 582.9 secHalting at iteration  185  of  7000
# Could not generate output statistics for a_subj.13
# Could not generate output statistics for z_Intercept_subj.26
# Could not generate output statistics for a_subj.22
# Could not generate output statistics for z_Intercept_subj.15
# Could not generate output statistics for a_subj.7
# Could not generate output statistics for v_Intercept_subj.2
# Could not generate output statistics for a_subj.18
# Could not generate output statistics for a_subj.3
# Could not generate output statistics for z_Intercept_subj_trans.4
# Could not generate output statistics for t_subj.14
# Could not generate output statistics for v_Intercept
# Could not generate output statistics for z_Intercept_subj.0
# Could not generate output statistics for z_Intercept_subj.27
# Could not generate output statistics for t_subj.12
# Could not generate output statistics for z_Intercept_subj_trans.19
# Could not generate output statistics for a_subj.17
# Could not generate output statistics for z_Intercept_subj_trans.2
# Could not generate output statistics for z_Intercept_subj_trans.17
# Could not generate output statistics for z_Intercept_subj_trans.26
# Could not generate output statistics for v_Intercept_subj.20
# Could not generate output statistics for a_subj.23
# Could not generate output statistics for t_subj.18
# Could not generate output statistics for z_Intercept_subj.25
# Could not generate output statistics for t_std
# Could not generate output statistics for z_Intercept_subj.28
# Could not generate output statistics for a_subj.11
# Could not generate output statistics for t_subj.19
# Could not generate output statistics for a_subj.16
# Could not generate output statistics for t_subj.11
# Could not generate output statistics for z_Intercept_subj_trans.21
# Could not generate output statistics for a_subj.21
# Could not generate output statistics for z_Intercept_subj.11
# Could not generate output statistics for a_subj.14
# Could not generate output statistics for a_subj.24
# Could not generate output statistics for z_Intercept_subj_trans.14
# Could not generate output statistics for z_Intercept_subj_trans.18
# Could not generate output statistics for a_subj.5
# Could not generate output statistics for t_subj.6
# Could not generate output statistics for a_subj.9
# Could not generate output statistics for z_Intercept_subj_trans.11
# Could not generate output statistics for z_Intercept_subj_trans.29
# Could not generate output statistics for z_Intercept_subj_trans.23
# Could not generate output statistics for a_std
# Could not generate output statistics for v_Intercept_subj.23
# Could not generate output statistics for a_subj.15
# Could not generate output statistics for a_subj.6
# Could not generate output statistics for z_Intercept_subj_trans.25
# Could not generate output statistics for t_subj.13
# Could not generate output statistics for v_Intercept_subj.22
# Could not generate output statistics for v_Intercept_subj.1
# Could not generate output statistics for z_Intercept_subj.10
# Could not generate output statistics for a_subj.12
# Could not generate output statistics for a_subj.19
# Could not generate output statistics for t_subj.16
# Could not generate output statistics for t_subj.26
# Could not generate output statistics for a_subj.10
# Could not generate output statistics for z_Intercept_subj_trans.12
# Could not generate output statistics for t_subj.15
# Could not generate output statistics for v_Intercept_std
# Could not generate output statistics for z_Intercept_subj_trans.16
# Could not generate output statistics for z_Intercept_subj.5
# Could not generate output statistics for t_subj.21
# Could not generate output statistics for v_Intercept_subj.21
# Could not generate output statistics for z_Intercept_subj.24
# Could not generate output statistics for t_subj.8
# Could not generate output statistics for z_Intercept_subj_trans.27
# Could not generate output statistics for t_subj.5
# Could not generate output statistics for z_Intercept_trans
# Could not generate output statistics for z_Intercept_subj_trans.1
# Could not generate output statistics for t_subj.25
# Could not generate output statistics for v_Intercept_subj.28
# Could not generate output statistics for z_Intercept_subj.19
# Could not generate output statistics for v_Intercept_subj.8
# Could not generate output statistics for a_subj.1
# Could not generate output statistics for z_Intercept_subj.4
# Could not generate output statistics for z_Intercept_subj.7
# Could not generate output statistics for a_subj.2
# Could not generate output statistics for t_subj.3
# Could not generate output statistics for v_Intercept_subj.11
# Could not generate output statistics for t
# Could not generate output statistics for t_subj.0
# Could not generate output statistics for v_Intercept_subj.5
# Could not generate output statistics for t_subj.4
# Could not generate output statistics for v_C(condition)[T.level3]
# Could not generate output statistics for t_subj.22
# Could not generate output statistics for v_C(condition)[T.level2]
# Could not generate output statistics for z_Intercept_subj_trans.7
# Could not generate output statistics for v_Intercept_subj.15
# Could not generate output statistics for v_Intercept_subj.4
# Could not generate output statistics for z_Intercept_subj.12
# Could not generate output statistics for z_Intercept_subj.23
# Could not generate output statistics for z_Intercept_subj.2
# Could not generate output statistics for z_Intercept_subj.22
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-d7499c596ddf> in <module>
#       4 reg_descr1 = [z_reg1, v_reg1]
#       5 m_reg1 = hddm.HDDMRegressor(mydata, reg_descr1, include='z')
# ----> 6 m_reg1.sample(7000, burn=2000)
#       7 m_reg1.print_stats()
#
# /opt/conda/lib/python3.7/site-packages/kabuki/hierarchical.py in sample(self, *args, **kwargs)
#     653         self.sampled = True
#     654
# --> 655         self.gen_stats()
#     656         return self.mc
#     657
#
# /opt/conda/lib/python3.7/site-packages/kabuki/hierarchical.py in gen_stats(self, fname, print_hidden, **kwargs)
#     730             print_hidden <bool>  - print statistics of hidden nodes
#     731         """
# --> 732         self.append_stats_to_nodes_db()
#     733
#     734         sliced_db = self.nodes_db.copy()
#
# /opt/conda/lib/python3.7/site-packages/kabuki/hierarchical.py in append_stats_to_nodes_db(self, *args, **kwargs)
#     782             if self.nodes_db.loc[name, 'hidden']:
#     783                 continue
# --> 784             self.nodes_db.loc[name, 'mean']   = i_stats['mean']
#     785             self.nodes_db.loc[name, 'std']    = i_stats['standard deviation']
#     786             self.nodes_db.loc[name, '2.5q']   = i_stats['quantiles'][2.5]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
print(1/(1 + np.exp(-(0.149))))
print(1/(1 + np.exp(-(0.149 + 0.1063))))
print(1/(1 + np.exp(-(0.149 + 0.555))))
# Out:
# 0.5371812370524195
# 0.563480578731794
# 0.6690740262512676

# %%
# M2: replace the stim, instead of using dmatrix, 
#     we derive a column called stim in my data

# re-code the stimulus, 1 to 1, 2 to -1
mydata['stim'] = np.where(mydata['stimulus'] == 1.0, 1.0, -1.0) 

def z_link_func2(x, data=mydata):
    stim = data['stim']
    return 1/(1+np.exp(-np.multiply(x, stim))) # change `x.to_frame()` to `x`

z_reg2 = {'model': 'z ~ 1 + C(condition)', 'link_func': z_link_func2}
v_reg2 = {'model': 'v ~ 1 + C(condition)', 'link_func': lambda x: x}
reg_descr2 = [z_reg2, v_reg2]
m_reg2 = hddm.HDDMRegressor(mydata, reg_descr2, include='z')
m_reg2.sample(7000, burn=2000)

m_reg2.print_stats()
# Out:
# Adding these covariates:
# ['z_Intercept', 'z_C(condition)[T.level2]', 'z_C(condition)[T.level3]']
# Adding these covariates:
# ['v_Intercept', 'v_C(condition)[T.level2]', 'v_C(condition)[T.level3]']
#  [-----------------100%-----------------] 7001 of 7000 complete in 12350.2 sec                               mean         std        2.5q        25q        50q        75q        97.5q       mc err
# a                           1.99765    0.018618     1.96132    1.98525    1.99765    2.00981      2.03458  0.000294125
# a_std                     0.0892929   0.0154453   0.0633598  0.0783475   0.087698  0.0987664     0.123879  0.000372539
# a_subj.0                     1.9682   0.0365721     1.89801    1.94318    1.96756    1.99224      2.04257  0.000606918
# a_subj.1                    2.03841   0.0382852     1.96442     2.0117     2.0375    2.06434       2.1137  0.000694966
# a_subj.2                    1.89341   0.0408349     1.81418    1.86624    1.89264    1.92045      1.97531  0.000870052
# a_subj.3                    2.08027   0.0406225     2.00422    2.05332    2.07902    2.10695      2.16382  0.000754805
# a_subj.4                    1.90564   0.0395049     1.82881    1.87849    1.90419    1.93263      1.98468  0.000785896
# a_subj.5                    2.13689   0.0405516      2.0605    2.10932    2.13622    2.16388      2.21903  0.000784982
# a_subj.6                    1.95679    0.036959     1.88591    1.93159    1.95561    1.98191       2.0312  0.000767848
# a_subj.7                    2.08688   0.0416623     2.00628    2.05817    2.08692    2.11592      2.16738  0.000757451
# a_subj.8                    1.96697   0.0399824     1.89033    1.93892    1.96774    1.99372       2.0456  0.000741912
# a_subj.9                    1.91712   0.0375101     1.84606    1.89214    1.91599    1.94156       1.9942  0.000677065
# a_subj.10                   1.99815   0.0388878     1.92271    1.97157    1.99826    2.02398      2.07595  0.000849612
# a_subj.11                   1.99449   0.0372153     1.92293    1.96882    1.99455    2.01939       2.0689  0.000634717
# a_subj.12                   1.85799   0.0380813      1.7834    1.83218    1.85764    1.88317       1.9342  0.000826938
# a_subj.13                   2.02435   0.0380876      1.9519    1.99824    2.02406    2.05007      2.10059   0.00069352
# a_subj.14                   2.03531   0.0376466     1.96183     2.0098    2.03551    2.05981      2.11096  0.000666576
# a_subj.15                   2.01135   0.0385726     1.93625     1.9851    2.01077    2.03661      2.08923  0.000662092
# a_subj.16                   1.98062   0.0375589     1.90723    1.95592    1.98015    2.00557      2.05588  0.000669641
# a_subj.17                   1.86804   0.0372237     1.79486    1.84319      1.868    1.89326      1.93947  0.000619538
# a_subj.18                    2.1036   0.0421121     2.02407     2.0745    2.10219    2.13152      2.18804  0.000789888
# a_subj.19                   2.12667   0.0480975     2.03463    2.09461    2.12559    2.15886      2.22322   0.00107438
# a_subj.20                   1.93534   0.0359612     1.86525    1.91137    1.93463    1.95887      2.00824  0.000749466
# Plotting z_Intercept
# Plotting z_Intercept_std
# Plotting z_C(condition)[T.level2]
# Plotting z_C(condition)[T.level3]
# Plotting v_Intercept
# Plotting v_Intercept_std
# Plotting v_C(condition)[T.level2]
# Plotting v_C(condition)[T.level3]

# %%
from kabuki.analyze import check_geweke
check_geweke(m_reg2, assert_=False)
# Out:
# Chain of knode_name         a_subj
# stochastic           True
# observed            False
# subj                 True
# node             a_subj.0
# tag                    ()
# depends        [subj_idx]
# hidden              False
# rt                    NaN
# response              NaN
# subj_idx                0
# condition             NaN
# stimulus              NaN
# coding                NaN
# stim                  NaN
# mean               1.9682
# std             0.0365721
# 2.5q              1.89801
# 25q               1.94318
# 50q               1.96756
# 75q               1.99224
# 97.5q             2.04257
# mc err        0.000606918
# Name: a_subj.0, dtype: object not properly converged
# False

# %%
# M3: replace the inverse logit function

def z_link_func3(x, data=mydata):
    stim = (dmatrix('0 + C(s, [[1], [-1]])',
                    {'s':data.stimulus.loc[x.index]}, # original .ix is deprecated.
                    return_type="dataframe")
            )
    return np.multiply(x.to_frame(), stim) # we changed here

z_reg3 = {'model': 'z ~ 1 + C(condition)', 'link_func': z_link_func3}
v_reg3 = {'model': 'v ~ 1 + C(condition)', 'link_func': lambda x: x}
reg_descr3 = [z_reg3, v_reg3]
m_reg3 = hddm.HDDMRegressor(mydata, reg_descr3, include='z')
m_reg3.sample(7000, burn=2000)

m_reg3.print_stats()
# Out:
# Adding these covariates:
# ['z_Intercept', 'z_C(condition)[T.level2]', 'z_C(condition)[T.level3]']
# Adding these covariates:
# ['v_Intercept', 'v_C(condition)[T.level2]', 'v_C(condition)[T.level3]']
#  [-----------------100%-----------------] 7001 of 7000 complete in 22434.7 sec                                mean         std        2.5q        25q          50q        75q      97.5q       mc err
# a                             1.9302    0.021677     1.88869    1.91549      1.92992    1.94442    1.97355  0.000393733
# a_std                       0.099879   0.0185858   0.0687045  0.0867403    0.0984637   0.111322   0.142273  0.000525725
# a_subj.0                     1.99996    0.050693     1.90003    1.96584      1.99953    2.03439    2.10323  0.000946614
# a_subj.1                     1.96569   0.0511943     1.86608    1.93153      1.96491    1.99983     2.0648   0.00109547
# a_subj.2                     1.84677   0.0532726     1.74155    1.81024      1.84666    1.88207    1.95338   0.00103105
# a_subj.3                       1.979   0.0476326     1.89026    1.94567      1.97763    2.00944    2.07595  0.000884282
# a_subj.4                     1.93617   0.0516536     1.83832    1.90117      1.93552    1.97034    2.04067  0.000967135
# a_subj.5                     2.07164   0.0514876     1.97273    2.03713      2.07055    2.10513    2.17369    0.0010231
# a_subj.6                     1.90526   0.0512514     1.79835    1.87245       1.9056    1.93982    2.00136   0.00116884
# a_subj.7                     1.79977   0.0502165     1.70427    1.76503      1.79912    1.83428    1.89916   0.00118272
# a_subj.8                     1.81358   0.0473527     1.72082    1.78196      1.81365    1.84595    1.90593  0.000924593
# a_subj.9                     1.91194   0.0475203     1.81802    1.87998      1.91203     1.9442    2.00648  0.000788492
# a_subj.10                    1.91159   0.0486989     1.81665    1.87881      1.91126    1.94252    2.01324  0.000934497
# v_Intercept_subj.28         0.382557   0.0744893    0.242051   0.332275     0.381866   0.432267   0.531916   0.00169315
# v_Intercept_subj.29          0.54683   0.0807532    0.389643   0.491662       0.5454   0.601073   0.706682   0.00206742
# v_C(condition)[T.level2]    0.079634   0.0361368  0.00913323  0.0551172    0.0793715   0.104304    0.15225   0.00142799
# v_C(condition)[T.level3]     0.16769   0.0361474   0.0931932   0.143899     0.168224    0.19251   0.236041   0.00139214
# DIC: 119626.944096
# deviance: 119530.193903
# pD: 96.750193

# %%
print(0.50613)
print(0.50613 -0.099140)
print(0.50613 -0.191689)
# Out:
# 0.50613
# 0.40698999999999996
# 0.31444099999999997

# %%
# M4: replace the inverse logit function with recoding the `stim`
z_reg4 = {'model': 'z ~ 1 + C(condition)', 'link_func': lambda x: 1/(1+np.exp(-x))}
v_reg4 = {'model': 'v ~ 1 + C(condition)', 'link_func': lambda x: x}
reg_descr4 = [z_reg4, v_reg4]
m_reg4 = hddm.HDDMRegressor(mydata, reg_descr4, include='z')
m_reg4.sample(7000, burn=2000)

m_reg4.print_stats()
# Out:
# Adding these covariates:
# ['z_Intercept', 'z_C(condition)[T.level2]', 'z_C(condition)[T.level3]']
# Adding these covariates:
# ['v_Intercept', 'v_C(condition)[T.level2]', 'v_C(condition)[T.level3]']
#  [-----------------100%-----------------] 7001 of 7000 complete in 9658.8 sec                               mean         std        2.5q        25q         50q         75q      97.5q       mc err
# a                           1.94811   0.0189426     1.91036    1.93543     1.94813     1.96072    1.98596  0.000298266
# a_std                     0.0954543   0.0158556   0.0691456  0.0842464   0.0938918    0.104782   0.130988  0.000360399
# a_subj.0                    1.97972   0.0373259     1.90761    1.95452     1.97916     2.00457    2.05214  0.000740952
# a_subj.1                    2.01381   0.0386637     1.94031    1.98783     2.01275     2.03995    2.09201  0.000727189
# a_subj.2                    1.87419   0.0389454     1.79894    1.84736     1.87394     1.90109    1.95055  0.000819879
# a_subj.3                    1.99769   0.0391902      1.9246    1.97095     1.99665     2.02391    2.07717  0.000737783
# a_subj.4                    1.85935   0.0399241     1.78235    1.83219     1.85935     1.88549    1.94046  0.000853954
# a_subj.5                    2.08075   0.0405681     2.00307    2.05355     2.08001     2.10815    2.16203  0.000756059
# a_subj.6                    1.94034    0.038959     1.86598    1.91435     1.93847     1.96566    2.01984  0.000814875
# a_subj.7                    1.93359    0.036271     1.86341    1.90895     1.93351     1.95696    2.00684  0.000614894
# a_subj.8                    1.80049   0.0354407     1.73149    1.77618     1.80008     1.82441    1.87072  0.000733492
# a_subj.9                    1.86616   0.0372797     1.79478    1.84077     1.86626     1.89147     1.9395  0.000731882
# a_subj.10                   1.97618   0.0390915      1.9027    1.94886     1.97509     2.00288    2.05411  0.000791532
# a_subj.11                    1.9096   0.0390299     1.83451     1.8826     1.90924     1.93587    1.98851  0.000831298
# a_subj.12                   1.84301   0.0368666      1.7729    1.81825     1.84225     1.86814    1.91574  0.000702656
# a_subj.13                   2.02455   0.0406948     1.94768    1.99676     2.02377     2.05246    2.10509  0.000790304
# v_Intercept_subj.29        0.393207   0.0605074    0.273673   0.353246    0.392456    0.434322   0.514205    0.0014119
# v_C(condition)[T.level2]   0.275806    0.023071     0.23121   0.259997    0.275552    0.291821   0.320865   0.00068273
# v_C(condition)[T.level3]   0.369323    0.024625    0.320054   0.353042    0.368631    0.386505   0.417536  0.000792484
# DIC: 51255.822328
# deviance: 51148.872737
# pD: 106.949591

# %%
print(1/(1 + np.exp(-(0.180129))))
print(1/(1 + np.exp(-(0.180129 - 0.355723))))
print(1/(1 + np.exp(-(0.180129 - 0.324223))))
# Out:
# 0.5449108823675011
# 0.45621394776216245
# 0.46403870075879455

# %%
# M5: without link function at all
z_reg5 = {'model': 'z ~ 1 + C(condition)', 'link_func': lambda x: x}
v_reg5 = {'model': 'v ~ 1 + C(condition)', 'link_func': lambda x: x}
reg_descr5 = [z_reg5, v_reg5]
m_reg5 = hddm.HDDMRegressor(mydata, reg_descr5, include='z')
m_reg5.sample(7000, burn=2000)

m_reg5.print_stats()
# Out:
# Adding these covariates:
# ['z_Intercept', 'z_C(condition)[T.level2]', 'z_C(condition)[T.level3]']
# Adding these covariates:
# ['v_Intercept', 'v_C(condition)[T.level2]', 'v_C(condition)[T.level3]']
#  [-----------------100%-----------------] 7001 of 7000 complete in 9108.4 sec                                mean         std       2.5q        25q         50q         75q       97.5q       mc err
# a                            1.95151   0.0198514    1.91275    1.93849     1.95134     1.96462     1.99196  0.000337967
# a_std                      0.0996404   0.0163197  0.0722682  0.0880983    0.098113    0.109208    0.135622  0.000321853
# a_subj.0                     1.98431   0.0378372    1.91163     1.9583     1.98296      2.0099     2.05991  0.000727681
# a_subj.1                     2.01131   0.0394349    1.93411    1.98415     2.01109      2.0373     2.09124  0.000752101
# a_subj.2                     1.87338    0.039137    1.79913    1.84647     1.87338     1.89978      1.9492  0.000729995
# a_subj.3                      1.9973   0.0394679     1.9215    1.97017      1.9963     2.02337     2.07861  0.000757888
# a_subj.4                     1.85665   0.0402492    1.77856    1.82997     1.85654     1.88394     1.93595  0.000771951
# a_subj.5                     2.09526    0.040121    2.01854    2.06778     2.09458     2.12246      2.1751  0.000773815
# a_subj.6                     1.94586   0.0393598    1.87168    1.91958     1.94515     1.97205     2.02547  0.000793648
# a_subj.7                     1.93457   0.0368599    1.86279    1.90954     1.93383     1.95942     2.00816  0.000648943
# a_subj.8                     1.78329   0.0349976    1.71767    1.75916     1.78271     1.80678     1.85376  0.000803629
# a_subj.9                     1.86338   0.0366038    1.79101    1.83886     1.86315     1.88767     1.93562   0.00066186
# a_subj.10                    1.98101    0.039701    1.90413    1.95425      1.9812     2.00714     2.06065  0.000802969
# a_subj.11                    1.90306   0.0387238    1.82678    1.87768      1.9027     1.92931     1.97852  0.000855389
# a_subj.12                    1.84427   0.0362344    1.77367    1.82038     1.84435     1.86889     1.91416  0.000690475
# a_subj.13                    2.02565   0.0400997    1.94652    1.99797     2.02472     2.05321     2.10446  0.000732461
# a_subj.14                     2.0364   0.0410945    1.95628    2.00875     2.03531     2.06373     2.11882  0.000758805
# DIC: 50721.596532
# deviance: 50605.854533
# pD: 115.742000

# %%
print(1/(1 + np.exp(-(0.4867))))
print(1/(1 + np.exp(-(0.4867-0.0164))))
print(1/(1 + np.exp(-(0.4867-0.0094))))
# Out:
# 0.6193287291370335
# 0.6154547599094822
# 0.6171101067153784

# %% [markdown]
# Comparing the five models above, it's clear that only M1 and M2 recover the true `z`, at least the order of `z`, but the other three models do not.

# %% [markdown]
# We know that two models works, with or without using `dmatrix` to define the variable `stim`.
#
# Now, we go further to understand the **regression** we mentioned when talking about `x * stim`:
#
# `z_reg = {'model': 'z ~ 1 + C(condition)', 'link_func': z_link_func}`
#
# This is a formula for the model. Essentially, it is a generalized linear model (GLM). As a generalized linear model, it has three components (please see [here](https://towardsdatascience.com/generalized-linear-models-9cbf848bb8ab) for more):
#
# * Linear preidctor
# * Link function
# * probability distriubtion
#
# Translated into a more common form of formula, it may looks like this:
#
# $$x = b_{0} + b_{1}*condition_{i}$$
# $$z = invlogit(x)$$
# $$y_{i} \sim f(z)$$
#
# `x` is the x we mentioned above, it's the output of a linear regression;
#
# `z` is the `z` parameter of DDM, which is transformed to `x` so that it can be modelled as a regression. The `invlogit()` here is to implement the $z_{j} \sim invlogit(N(\mu_{z}, \sigma_{z}^{2}))$ in Wiecki et al (2013).
#
# `y` is the behavioral response, it should be pairs of RT and response
#
# `f` in the formula is part of DDM likelihood function

# %%
z_reg = {'model': 'z ~ 1 + C(condition)', 'link_func': z_link_func}

# %%
z_reg['link_func']
# Out:
# <function __main__.z_link_func(x, data=             rt  response  subj_idx condition  stimulus
# 0      1.079013       0.0         0    level1       1.0
# 1      1.100509       0.0         0    level1       1.0
# 2      0.384129       0.0         0    level1       1.0
# 3      0.531129       0.0         0    level1       1.0
# 4      0.444750       0.0         0    level1       1.0
# ...         ...       ...       ...       ...       ...
# 17995  0.485287       1.0        29    level3       2.0
# 17996  0.461082       0.0        29    level3       2.0
# 17997  0.364979       1.0        29    level3       2.0
# 17998  0.462025       0.0        29    level3       2.0
# 17999  0.441705       1.0        29    level3       2.0
#
# [18000 rows x 5 columns])>

# %% [markdown]
# This function semms quite myterious to beginners, but what exactly it does?
#
# Let's just check the `stim` inside the function. To check that, we need to figure out the input of the function.
#
# `data = mydata` is clear.
#
# `x` is a bit harder to understand. It is the regression output `x` (which is an array has the same size as `stim`, which should has the same size as stimulus. we can first remove the x and see what happen? there is an error!!

# %% [markdown]
# #### M1: Accuracy coding + HDDM
#
# The first model, use the simple between-subject design model and accuracy-coding. This looks like the most unlikely.
#
# m1 = hddm:HDDM(depends_on = {'v': [Stim, levels], 'z':[Stim, levels]},...)

# %%
m1 = hddm.HDDM(df_acc, depends_on={'v': ['condition', 'StimType'], 'z': ['condition', 'StimType']}, 
               include=['v', 'z', 't'],p_outlier=.05)

m1.find_starting_values()
m1.sample(2000,burn = 500, dbname='stim_sim_m1.db', db='pickle')
# 2001 of 2000 complete in 1797.8 sec

# save the model
m1.save('stim_sim_m1')

m1.print_stats()
# Out:
# /opt/conda/lib/python3.7/site-packages/scipy/optimize/optimize.py:1985: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# z_subj(right.level3).15   0.738387   0.0197631   0.698515   0.726175   0.738344   0.751674   0.775576  0.000639657
# z_subj(right.level3).16   0.468176   0.0308644   0.407562    0.44749   0.467545   0.489278   0.529785   0.00101147
# z_subj(right.level3).17   0.614365   0.0286184   0.558542   0.595312   0.614132   0.632678   0.672101   0.00098255
# z_subj(right.level3).18   0.383524   0.0286868   0.330219   0.363475    0.38327   0.402839   0.439994  0.000939316
# z_subj(right.level3).19   0.690786   0.0240154   0.641314   0.674974    0.69058   0.707589   0.735028  0.000961805
# z_subj(right.level3).20   0.531634   0.0304132   0.470391   0.510395   0.532665   0.552814   0.589076  0.000968234
# z_subj(right.level3).21   0.536133    0.029544   0.477265   0.516707   0.537126   0.556424   0.592952   0.00101154
# z_subj(right.level3).22   0.467855   0.0301055   0.407968   0.447392    0.46875   0.489123   0.522724  0.000925561
# z_subj(right.level3).23   0.416967   0.0283991   0.359452   0.397807   0.417597   0.435732   0.473099  0.000861801
# z_subj(right.level3).24   0.583087   0.0297275    0.52463   0.562282   0.582958   0.602572   0.640918   0.00103402
# z_subj(right.level3).25   0.574151   0.0290432   0.515978    0.55554   0.574772   0.594533   0.628051  0.000875277
# z_subj(right.level3).26   0.507252   0.0320587   0.446298   0.485929   0.507361   0.529675   0.567854   0.00102707
# z_subj(right.level3).27   0.441929   0.0304535   0.381337   0.422642   0.442433   0.460757   0.500129  0.000983671
# z_subj(right.level3).28   0.652621   0.0240715   0.601878   0.636803   0.652903    0.66933   0.696251  0.000894293
# z_subj(right.level3).29   0.599587   0.0275534   0.549809   0.581499    0.59935    0.61764   0.654356  0.000868796
# DIC: 49462.314083
# deviance: 49161.951753
# pD: 300.362330

# %%
# load the model data if it was previously saved
m1 = hddm.load('stim_sim_m1')

# %% [markdown]
# Check parameter recovery
#
# Check the correlation between recovered parameters and the ground truth.
#
# Also check the correlation between recovered parameters themselves to see if there exist trade-off between parameters.

# %%
def gen_params_comp(m, df_params):
    '''
    merge the group-level parameters from model fitting with the ground truth of simulation.
    for later plotting and correlation analysis
    '''
    
    m_stats = m.gen_stats()
    m_stats['params'] = m_stats.index
    m_stats.head()

    m_stats_subj = m_stats[m_stats['params'].str.contains("z_subj|v_subj")]
    m_stats_subj[['param','subj']] = m_stats_subj['params'].str.split("_",expand=True) 
    m_stats_subj[['subj','conds','subj_idx']] = m_stats_subj['subj'].str.split("\(|\)",expand=True) 

    # https://stackoverflow.com/questions/46124469/shape-mismatch-indexing-arrays-could-not-be-broadcast-together-with-shapes
    m_stats_subj[['subj_idx']] = m_stats_subj['subj_idx'].str.split(".",expand=True)[1][:,np.newaxis] 
    m_stats_subj[['StimType', 'condition']] = m_stats_subj['conds'].str.split(".",expand=True).loc[:,0:1]
    m_stats_subj = m_stats_subj.drop(['subj', 'conds'], axis=1).copy()

    m_stats_subj_wide = m_stats_subj.pivot_table(index=['subj_idx', 'condition', 'StimType'], 
                                     columns=['param'],
                                     aggfunc='first', 
                                     values = 'mean',     
                                     fill_value=0) 
    #m1_stats_subj_wide.columns = m1_stats_subj_wide.columns.map('_'.join)
    m_stats_subj_wide.reset_index(inplace=True)  

    # reset the index
    m_stats_subj_wide.index = df_params.index

    # change the data type of 'subj_idx'
    m_stats_subj_wide['subj_idx'] = m_stats_subj_wide['subj_idx'].astype(int)
    
    df_params_ppc = pd.merge(df_params, m_stats_subj_wide)
    return df_params_ppc

# %%
m_stats = m_reg2.gen_stats()
m_stats['params'] = m_stats.index
m_stats

# m_stats_subj[['param','subj']] = m_stats_subj['params'].str.split("_",expand=True)
# Out:
#                                mean        std       2.5q        25q  \
# a                           1.99765   0.018618    1.96132    1.98525
# a_std                     0.0892929  0.0154453  0.0633598  0.0783475
# a_subj.0                     1.9682  0.0365721    1.89801    1.94318
# a_subj.1                    2.03841  0.0382852    1.96442     2.0117
# a_subj.2                    1.89341  0.0408349    1.81418    1.86624
# ...                             ...        ...        ...        ...
# v_Intercept_subj.27        0.298568  0.0490813   0.200302   0.265194
# v_Intercept_subj.28        0.559698  0.0537048   0.456264   0.523517
# v_Intercept_subj.29        0.659605   0.049616   0.560998   0.625739
# v_C(condition)[T.level2]  0.0943087  0.0204479  0.0541927  0.0804991
# v_C(condition)[T.level3]   0.208782   0.021634   0.165485   0.194513
#
#                                 50q        75q     97.5q       mc err  \
# a                           1.99765    2.00981   2.03458  0.000294125
# a_std                      0.087698  0.0987664  0.123879  0.000372539
# a_subj.0                    1.96756    1.99224   2.04257  0.000606918
# a_subj.1                     2.0375    2.06434    2.1137  0.000694966
# a_subj.2                    1.89264    1.92045   1.97531  0.000870052
# ...                             ...        ...       ...          ...
# v_Intercept_subj.27        0.298603   0.331641   0.39519  0.000806313
# v_Intercept_subj.28        0.559293   0.596213  0.664969  0.000879813
# v_Intercept_subj.29        0.660431    0.69336  0.756018  0.000926961
# v_C(condition)[T.level2]  0.0942904   0.108428  0.134931  0.000574851
# v_C(condition)[T.level3]   0.208738   0.223776  0.251394  0.000590704
#
#                                             params
# a                                                a
# a_std                                        a_std
# a_subj.0                                  a_subj.0
# a_subj.1                                  a_subj.1
# a_subj.2                                  a_subj.2
# ...                                            ...
# v_Intercept_subj.27            v_Intercept_subj.27
# v_Intercept_subj.28            v_Intercept_subj.28
# v_Intercept_subj.29            v_Intercept_subj.29
# v_C(condition)[T.level2]  v_C(condition)[T.level2]
# v_C(condition)[T.level3]  v_C(condition)[T.level3]
#
# [132 rows x 9 columns]

# %%
m_stats_subj = m_stats[m_stats['params'].str.contains("z_|v_")]
m_stats_subj.head()
# Out:
#                          mean        std       2.5q        25q        50q  \
# z_Intercept            0.1491  0.0168362   0.118097   0.137883   0.148461
# z_Intercept_std      0.580244  0.0281658   0.527038   0.561292   0.579927
# z_Intercept_subj.0  0.0271589  0.0093457  0.0121588  0.0204472  0.0260808
# z_Intercept_subj.1   0.133389  0.0402789  0.0612582   0.104652    0.13146
# z_Intercept_subj.2  0.0293478    0.01028  0.0129039  0.0218342  0.0281088
#
#                          75q      97.5q       mc err              params
# z_Intercept         0.159653   0.184013  0.000472394         z_Intercept
# z_Intercept_std     0.599161   0.636541  0.000560368     z_Intercept_std
# z_Intercept_subj.0  0.032683  0.0482075  0.000149908  z_Intercept_subj.0
# z_Intercept_subj.1  0.159762   0.219765  0.000714949  z_Intercept_subj.1
# z_Intercept_subj.2  0.035663  0.0525992  0.000178227  z_Intercept_subj.2

# %%
tmp = gen_params_comp(m_reg2, df_params)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-b10fc580a6ab> in <module>
# ----> 1 tmp = gen_params_comp(m_reg2, df_params)
#
# <ipython-input-36-c4f5b700a7e7> in gen_params_comp(m, df_params)
#      10
#      11     m_stats_subj = m_stats[m_stats['params'].str.contains("z_subj|v_subj")]
# ---> 12     m_stats_subj[['param','subj']] = m_stats_subj['params'].str.split("_",expand=True)
#      13     m_stats_subj[['subj','conds','subj_idx']] = m_stats_subj['subj'].str.split("\(|\)",expand=True)
#      14
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2933             self._setitem_frame(key, value)
#    2934         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 2935             self._setitem_array(key, value)
#    2936         else:
#    2937             # set column
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    2959             if isinstance(value, DataFrame):
#    2960                 if len(value.columns) != len(key):
# -> 2961                     raise ValueError("Columns must be same length as key")
#    2962                 for k1, k2 in zip(key, value.columns):
#    2963                     self[k1] = value[k2]
#
# ValueError: Columns must be same length as key

# %%
# correlation between variables.
tmp.groupby(['StimType', 'condition'])[['v','v_pop','z', 'z_pop']].corr()
# Out:
#                                  v     v_pop         z     z_pop
# StimType condition
# left     level1    v      1.000000  0.501747  0.327299  0.444686
#                    v_pop  0.501747  1.000000  0.094512  0.089086
#                    z      0.327299  0.094512  1.000000  0.913195
#                    z_pop  0.444686  0.089086  0.913195  1.000000
#          level2    v      1.000000  0.608738  0.399344  0.469079
#                    v_pop  0.608738  1.000000  0.112050  0.089086
#                    z      0.399344  0.112050  1.000000  0.956915
#                    z_pop  0.469079  0.089086  0.956915  1.000000
#          level3    v      1.000000  0.445186  0.528031  0.626526
#                    v_pop  0.445186  1.000000  0.037261  0.089086
#                    z      0.528031  0.037261  1.000000  0.890952
#                    z_pop  0.626526  0.089086  0.890952  1.000000
# right    level1    v      1.000000  0.623415  0.602548  0.650414
#                    v_pop  0.623415  1.000000  0.154305  0.089086
#                    z      0.602548  0.154305  1.000000  0.916975
#                    z_pop  0.650414  0.089086  0.916975  1.000000
#          level2    v      1.000000  0.503719  0.388509  0.474410
#                    v_pop  0.503719  1.000000  0.060762  0.089086
#                    z      0.388509  0.060762  1.000000  0.954857
#                    z_pop  0.474410  0.089086  0.954857  1.000000
#          level3    v      1.000000  0.611886  0.608920  0.617683
#                    v_pop  0.611886  1.000000  0.044423  0.089086
#                    z      0.608920  0.044423  1.000000  0.937347
#                    z_pop  0.617683  0.089086  0.937347  1.000000

# %%
sns.set(style="ticks", color_codes=True, font_scale=1.3)

g = sns.pairplot(tmp.loc[tmp['StimType'] == 'left', ['v', 'z', 'v_pop', 'z_pop','condition']], 
                 hue="condition", palette="bright", 
                 #plot_kws=dict(edgecolor='none', alpha=0.5),
                 kind="reg",
                 height = 4, corner=True) # or linewidth=0
plt.setp(g._legend.get_title(), fontsize=18)
# Out:
# [None, None]

# %%
# pair plot for right stimuli
sns.set(style="ticks", color_codes=True, font_scale=1.3)

g = sns.pairplot(tmp.loc[tmp['StimType'] == 'right', ['v', 'z', 'v_pop', 'z_pop','condition']], 
                 hue="condition", palette="bright", 
                 #plot_kws=dict(edgecolor='none', alpha=0.5),
                 kind="reg",
                 height = 4, corner=True) # or linewidth=0
plt.setp(g._legend.get_title(), fontsize=18)
# Out:
# [None, None]

# %% [markdown]
# Another step could be used for mode recovery: PPC.

# %%
m1_ppc_data = hddm.utils.post_pred_gen(m1)
#m1_ppc_data.head()

ppc_compare = hddm.utils.post_pred_stats(df_acc, m1_ppc_data)
print(ppc_compare)
# Out:
#  [-----------------101%-----------------] 183 of 180 complete in 1689.5 sec          observed      mean       std       SEM       MSE credible  \
# stat
# accuracy  0.659222  0.665869  0.137265  0.000044  0.018884     True
# mean_ub   1.248360  1.236255  0.237438  0.000147  0.056524     True
# std_ub    0.794891  0.718103  0.150149  0.005896  0.028441     True
# 10q_ub    0.505003  0.580049  0.143958  0.005632  0.026355     True
# 30q_ub    0.753127  0.782205  0.187116  0.000846  0.035858     True
# 50q_ub    1.027213  1.025537  0.231574  0.000003  0.053630     True
# 70q_ub    1.422330  1.388872  0.289152  0.001119  0.084730     True
# 90q_ub    2.298006  2.154882  0.416715  0.020485  0.194137     True
# mean_lb  -1.183679 -1.173289  0.202504  0.000108  0.041116     True
# std_lb    0.763513  0.688057  0.186492  0.005694  0.040473     True
# 10q_lb    0.496125  0.557219  0.132461  0.003732  0.021278     True
# 30q_lb    0.705962  0.737965  0.166425  0.001024  0.028722     True
# 50q_lb    0.955878  0.964275  0.206701  0.000071  0.042796     True
# 70q_lb    1.328032  1.310133  0.266269  0.000320  0.071220     True
# 90q_lb    2.197012  2.034235  0.420782  0.026496  0.203550     True
#
#            quantile  mahalanobis
# stat
# accuracy  44.981110     0.048420
# mean_ub   52.165554     0.050981
# std_ub    71.922226     0.511413
# 10q_ub    30.412222     0.521302
# 30q_ub    44.664444     0.155401
# 50q_ub    50.632221     0.007236
# 70q_ub    55.054443     0.115709
# 90q_ub    65.437775     0.343459
# mean_lb   45.834446     0.051310
# std_lb    69.067780     0.404607
# 10q_lb    31.972221     0.461222
# 30q_lb    45.230000     0.192294
# 50q_lb    51.228889     0.040623
# 70q_lb    55.531113     0.067222
# 90q_lb    68.132225     0.386843

# %%
ppc_stats = hddm.utils.post_pred_stats(df_acc, m1_ppc_data, call_compare=False)
print(ppc_stats.head())
# Out:
#                             accuracy   mean_ub    std_ub    10q_ub    30q_ub  \
# node                sample
# wfpt(left.level1).0 0           0.22  1.911798  1.221440  0.947026  1.238676
#                     1           0.32  1.906606  1.277204  0.707869  1.373119
#                     2           0.34  1.511916  0.726405  0.746936  1.049276
#                     3           0.28  1.441306  0.695525  0.799554  0.958294
#                     4           0.33  2.021173  1.472641  0.935422  1.199442
#
#                               50q_ub    70q_ub    90q_ub   mean_lb    std_lb  \
# node                sample
# wfpt(left.level1).0 0       1.508126  1.869536  2.950546 -0.845492  0.625802
#                     1       1.613609  1.930439  3.217469 -0.709554  0.656929
#                     2       1.324866  1.883656  2.410316 -0.854033  0.622987
#                     3       1.191374  1.568134  2.427834 -0.731456  0.691789
#                     4       1.417881  1.872082  5.014401 -0.674796  0.613003
#
#                               10q_lb    30q_lb    50q_lb    70q_lb    90q_lb
# node                sample
# wfpt(left.level1).0 0       0.372776  0.446426  0.593306  0.918846  1.634666
#                     1       0.328110  0.391460  0.438990  0.618070  1.332300
#                     2       0.364996  0.436096  0.623196  0.805046  1.851446
#                     3       0.337224  0.375194  0.457654  0.634494  1.601884
#                     4       0.325922  0.386802  0.473162  0.572162  1.258762

# %%
m1.plot_posterior_predictive()

# %% [markdown]
# #### M2: Stimcoding with HDDMStimcoding: Way 1
#
# This model still use between-subj design, but use the stimcoding as assumed in the tutorial, i.e., assuming that the response doesn't matter.
#
# m2 = hddm:HDDMStimcoding(depends_on = {'v': [levels], 'z':[levels]}, ...)
#
# Even the number of parameters are different from recovered here and the ground truth data, we nevertheless tried to compare them.

# %%
# Should not use 'data = df_stim'
m2 = hddm.HDDMStimCoding(df_stim, include=['z'],
                         stim_col='stim',
                         depends_on={'v': ['condition'], 'z':['condition']}, 
                         p_outlier=.05,
                         split_param='v',
                         drift_criterion=False)                                    

m2.find_starting_values()
m2.sample(2000,burn = 500, dbname='stim_sim_m2.db', db='pickle')
2001 of 2000 complete in 1699.4 sec 

# save the model
m2.save('stim_sim_m2')
#C_val_vtz = hddm.load('C_val_vtz')

m2.print_stats()
# Out:
# /opt/conda/lib/python3.7/site-packages/scipy/optimize/optimize.py:1985: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
#  [-----------------100%-----------------] 2001 of 2000 complete in 1699.4 sec                       mean       std      2.5q       25q       50q       75q     97.5q    mc err
# a                  1.958776  0.022294  1.916160  1.943811  1.958509  1.973451  2.003572  0.000731
# a_std              0.108780  0.016422  0.080732  0.097186  0.107166  0.119231  0.144351  0.000597
# a_subj.0           1.911967  0.041124  1.832726  1.883309  1.912270  1.939656  1.991499  0.001551
# a_subj.1           1.941747  0.038983  1.864347  1.916045  1.942007  1.968111  2.016992  0.001389
# a_subj.2           2.020687  0.040153  1.943897  1.994180  2.021255  2.048286  2.099066  0.001302
# a_subj.3           1.982271  0.040073  1.905202  1.954586  1.983241  2.009772  2.059926  0.001342
# a_subj.4           2.088061  0.041608  2.004084  2.060009  2.089032  2.116187  2.171952  0.001409
# a_subj.5           2.054791  0.044463  1.967485  2.025146  2.055512  2.085140  2.139976  0.001570
# a_subj.6           1.886480  0.037140  1.814558  1.861781  1.885595  1.910367  1.962595  0.001243
# a_subj.7           2.019561  0.041279  1.943003  1.989854  2.018969  2.048194  2.105344  0.001477
# a_subj.8           1.785316  0.037103  1.714942  1.760853  1.785861  1.809910  1.858915  0.001488
# a_subj.9           1.817119  0.044016  1.732692  1.785968  1.816011  1.847409  1.903320  0.001849
# a_subj.10          1.955332  0.039471  1.877749  1.928627  1.955262  1.982922  2.033317  0.001362
# z_subj(right.level3).28  0.650810  0.024705  0.601127  0.633964  0.651825  0.668845  0.697760  0.000806
# z_subj(right.level3).29  0.599780  0.026672  0.543052  0.582325  0.599890  0.617340  0.650244  0.000895
# DIC: 49463.293248
# deviance: 49164.562108
# pD: 298.731140

# %%
# load the model data if it was previously saved
m3 = hddm.load('stim_sim_m3')

# %%
tmp = gen_params_comp(m3, df_params)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:2969: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.loc._setitem_with_indexer((slice(None), indexer), value)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:2935: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_array(key, value)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
# correlation between variables.
tmp.groupby(['StimType', 'condition'])[['v','v_pop','z', 'z_pop']].corr()
# Out:
#                                  v     v_pop         z     z_pop
# StimType condition
# left     level1    v      1.000000  0.506216 -0.342637  0.444934
#                    v_pop  0.506216  1.000000 -0.093796  0.089086
#                    z     -0.342637 -0.093796  1.000000 -0.915558
#                    z_pop  0.444934  0.089086 -0.915558  1.000000
#          level2    v      1.000000  0.599184 -0.400570  0.471753
#                    v_pop  0.599184  1.000000 -0.120543  0.089086
#                    z     -0.400570 -0.120543  1.000000 -0.954903
#                    z_pop  0.471753  0.089086 -0.954903  1.000000
#          level3    v      1.000000  0.453420 -0.540466  0.638310
#                    v_pop  0.453420  1.000000 -0.038127  0.089086
#                    z     -0.540466 -0.038127  1.000000 -0.890419
#                    z_pop  0.638310  0.089086 -0.890419  1.000000
# right    level1    v      1.000000  0.626490  0.592004  0.643610
#                    v_pop  0.626490  1.000000  0.152491  0.089086
#                    z      0.592004  0.152491  1.000000  0.915930
#                    z_pop  0.643610  0.089086  0.915930  1.000000
#          level2    v      1.000000  0.504162  0.393574  0.478989
#                    v_pop  0.504162  1.000000  0.060183  0.089086
#                    z      0.393574  0.060183  1.000000  0.954219
#                    z_pop  0.478989  0.089086  0.954219  1.000000
#          level3    v      1.000000  0.612804  0.605998  0.610724
#                    v_pop  0.612804  1.000000  0.048300  0.089086
#                    z      0.605998  0.048300  1.000000  0.937610
#                    z_pop  0.610724  0.089086  0.937610  1.000000

# %%
sns.set(style="ticks", color_codes=True, font_scale=1.3)

g = sns.pairplot(tmp.loc[tmp['StimType'] == 'left', ['v', 'z', 'v_pop', 'z_pop','condition']], 
                 hue="condition", palette="bright", 
                 #plot_kws=dict(edgecolor='none', alpha=0.5),
                 kind="reg",
                 height = 4, corner=True) # or linewidth=0
plt.setp(g._legend.get_title(), fontsize=18)
# Out:
# [None, None]

# %%
sns.set(style="ticks", color_codes=True, font_scale=1.3)

g = sns.pairplot(tmp.loc[tmp['StimType'] == 'right', ['v', 'z', 'v_pop', 'z_pop','condition']], 
                 hue="condition", palette="bright", 
                 #plot_kws=dict(edgecolor='none', alpha=0.5),
                 kind="reg",
                 height = 4, corner=True) # or linewidth=0
plt.setp(g._legend.get_title(), fontsize=18)
# Out:
# [None, None]

# %% [markdown]
# #### M4: Accuracy-coding + regressor
# That is, we treat the data as accuracy-coding with within-subject design. The pseudo code is like:
#
# m4 = hddm:HDDMRegressor{ 'v' ~ Stim * levels, 'z' ~ stim * levels, 'link_func':lambda x:1/(1+np.exp(-x))}

# %% [markdown]
# For reduced-rank coding, one level is chosen as the “reference”, and its mean behaviour is represented by the intercept. Each column of the resulting matrix represents the difference between the mean of one level and this reference level.
#
# For full-rank coding, classic “dummy” coding is used, and each column of the resulting matrix represents the mean of the corresponding level.
#
# https://patsy.readthedocs.io/en/latest/API-reference.html#handling-categorical-data

# %% [markdown]
# $v_{ij} = v_{int} + v_{intsubj} + \beta_{i} * cond_{}i$
#
# $i$ is the condition;
#
# $j$ is the subject index

# %%
# full rank coding
dmatrix("0 + C(condition, Treatment) * C(StimType, Treatment)", data=df_acc)
# Out:
# DesignMatrix with shape (18000, 6)
#   Columns:
#     ['C(condition, Treatment)[level1]',
#      'C(condition, Treatment)[level2]',
#      'C(condition, Treatment)[level3]',
#      'C(StimType, Treatment)[T.right]',
#      'C(condition, Treatment)[T.level2]:C(StimType, Treatment)[T.right]',
#      'C(condition, Treatment)[T.level3]:C(StimType, Treatment)[T.right]']
#   Terms:
#     'C(condition, Treatment)' (columns 0:3)
#     'C(StimType, Treatment)' (column 3)
#     'C(condition, Treatment):C(StimType, Treatment)' (columns 4:6)
#   (to view full data, use np.asarray(this_obj))

# %%
# reduced rank coding
dmatrix("C(condition, Treatment) * C(StimType, Treatment)", data=df_acc)
# Out:
# DesignMatrix with shape (18000, 6)
#   Columns:
#     ['Intercept',
#      'C(condition, Treatment)[T.level2]',
#      'C(condition, Treatment)[T.level3]',
#      'C(StimType, Treatment)[T.right]',
#      'C(condition, Treatment)[T.level2]:C(StimType, Treatment)[T.right]',
#      'C(condition, Treatment)[T.level3]:C(StimType, Treatment)[T.right]']
#   Terms:
#     'Intercept' (column 0)
#     'C(condition, Treatment)' (columns 1:3)
#     'C(StimType, Treatment)' (column 3)
#     'C(condition, Treatment):C(StimType, Treatment)' (columns 4:6)
#   (to view full data, use np.asarray(this_obj))

# %%
z_reg4 = {'model': "z ~ 1 + C(condition,Treatment('level1')) * C(StimType, Treatment('left'))", 
         'link_func': lambda x:1/(1+np.exp(-x))}

v_reg4 = {'model': "v ~ 1 + C(condition,Treatment('level1')) * C(StimType, Treatment('left'))", 
         'link_func': lambda x:x}

reg_descr4 = [z_reg4, v_reg4]

# Note here the 'group_only_regresors' is set to 'false'
m4 = hddm.HDDMRegressor(df_acc, reg_descr4, group_only_regressors=False, keep_regressor_trace=True, include='z')

m4.find_starting_values()

m4.sample(2000, burn=500, dbname='stim_sim_m4.db', db='pickle') # 7688.0 sec

# save the model
m4.save('stim_sim_m4')
# m4 = hddm.load('stim_sim_m4')

m4.print_stats()
# Out:
# Adding these covariates:
# ['z_Intercept', "z_C(condition, Treatment('level1'))[T.level2]", "z_C(condition, Treatment('level1'))[T.level3]", "z_C(StimType, Treatment('left'))[T.right]", "z_C(condition, Treatment('level1'))[T.level2]:C(StimType, Treatment('left'))[T.right]", "z_C(condition, Treatment('level1'))[T.level3]:C(StimType, Treatment('left'))[T.right]"]
# Adding these covariates:
# ['v_Intercept', "v_C(condition, Treatment('level1'))[T.level2]", "v_C(condition, Treatment('level1'))[T.level3]", "v_C(StimType, Treatment('left'))[T.right]", "v_C(condition, Treatment('level1'))[T.level2]:C(StimType, Treatment('left'))[T.right]", "v_C(condition, Treatment('level1'))[T.level3]:C(StimType, Treatment('left'))[T.right]"]
# /opt/conda/lib/python3.7/site-packages/scipy/optimize/optimize.py:1985: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# v_Intercept_subj.29                                                                     0.202934   0.0633801    0.085013   0.159821   0.204405   0.245022    0.330857   0.00315104
# v_C(condition, Treatment('level1'))[T.level2]                                           0.281549   0.0335294    0.219364   0.258418   0.282016   0.306581    0.341608   0.00234616
# v_C(condition, Treatment('level1'))[T.level3]                                           0.263138   0.0324095    0.200725    0.23951   0.263375   0.285753    0.326181   0.00224368
# v_C(StimType, Treatment('left'))[T.right]                                               0.283191   0.0309609    0.221162   0.263158   0.283528   0.303514    0.342942   0.00238148
# v_C(condition, Treatment('level1'))[T.level2]:C(StimType, Treatment('left'))[T.right]  -0.208619   0.0480581   -0.305439  -0.241997  -0.208555  -0.175481   -0.119163   0.00350162
# v_C(condition, Treatment('level1'))[T.level3]:C(StimType, Treatment('left'))[T.right] -0.0629311   0.0473741   -0.159265 -0.0932423 -0.0629836 -0.0295695   0.0246041   0.00342482
# DIC: 50022.909905
# deviance: 49907.169042
# pD: 115.740862

# %%
m4 = hddm.load('stim_sim_m4')
# Out:
# WARNING: Custom link functions will not be loaded.

# %%
m_traces = m4.get_traces()
slct_col_names = m_traces.columns[m_traces.columns.str.contains("z_")]
m_traces = m_traces[slct_col_names].copy()

slct_col_names
trace_name = m_traces.columns[m_traces.columns.str.contains("subj.0|subj_trans.0")]

trace_name
# Out:
# Index(['z_Intercept_subj_trans.0',
#        'z_C(condition, Treatment('level1'))[T.level2]_subj.0',
#        'z_C(condition, Treatment('level1'))[T.level3]_subj.0',
#        'z_C(StimType, Treatment('left'))[T.right]_subj.0',
#        'z_C(condition, Treatment('level1'))[T.level2]:C(StimType, Treatment('left'))[T.right]_subj.0',
#        'z_C(condition, Treatment('level1'))[T.level3]:C(StimType, Treatment('left'))[T.right]_subj.0'],
#       dtype='object')

# %%
subj_id = 0
subj_name = 'subj.' + str(subj_id)

l_l1_name = 'z' + "_Intercept_subj_trans." + str(subj_id)
l_l2_eff_name = 'z' + "_C(condition, Treatment('level1'))[T.level2]_" + subj_name
l_l3_eff_name = 'z' + "_C(condition, Treatment('level1'))[T.level3]_" + subj_name
r_l1_eff_name = 'z' + "_C(StimType, Treatment('left'))[T.right]_" + subj_name
r_l2_int_name = 'z' + "_C(condition, Treatment('level1'))[T.level2]:C(StimType, Treatment('left'))[T.right]_" + subj_name
r_l3_int_name = 'z' + "_C(condition, Treatment('level1'))[T.level3]:C(StimType, Treatment('left'))[T.right]_" + subj_name

tmp_l_l1 = m_traces[l_l1_name].copy()
#1/(1+np.exp(-x))
# exp(z_trans)/(1+exp(z_trans)) 
#tmp_l_l1 = 1/(1+np.exp(-tmp_l_l1))
tmp_l_l1 = np.exp(tmp_l_l1)/(1+np.exp(tmp_l_l1))

tmp_l_l2 = m_traces[l_l2_eff_name].copy()
tmp_l_l2 = np.exp(tmp_l_l2)/(1+np.exp(tmp_l_l2))

tmp_l_l3 = tmp_l_l1 + m_traces[l_l3_eff_name].copy()
tmp_l_l3 = np.exp(tmp_l_l3)/(1+np.exp(tmp_l_l3))

tmp_r_l1 = tmp_l_l1 + m_traces[r_l1_eff_name].copy()
tmp_r_l1 = np.exp(tmp_r_l1)/(1+np.exp(tmp_r_l1))

tmp_r_l2 = tmp_r_l1 + m_traces[r_l2_int_name].copy()
tmp_r_l2 = np.exp(tmp_r_l2)/(1+np.exp(tmp_r_l2))

tmp_r_l3 = tmp_r_l1 + m_traces[r_l3_int_name].copy()
tmp_r_l3 = np.exp(tmp_r_l3)/(1+np.exp(tmp_r_l3))

dd = pd.concat([tmp_l_l1, tmp_l_l2, tmp_l_l3, tmp_r_l1, tmp_r_l2, tmp_r_l3], axis=1)
dd.columns = ['left_level1_value', 'left_level2_value', 'left_level3_value', 
              'right_level1_value', 'right_level2_value', 'right_level3_value']
dd
# df_subj_traces = pd.DataFrame(columns = ['params','subj_idx', 'left_level1_value', 'left_level2_value',
#                                          'left_level3_value', 'right_level1_value', 'right_level2_value', 
#                                          'right_level3_value'])
# Out:
#       left_level1_value  left_level2_value  left_level3_value  \
# 0              0.028198           0.365616           0.369432
# 1              0.029951           0.362269           0.361146
# 2              0.028510           0.350889           0.384077
# 3              0.029658           0.381358           0.377944
# 4              0.028211           0.361473           0.373288
# ...                 ...                ...                ...
# 1495           0.034222           0.393462           0.451006
# 1496           0.025281           0.386290           0.400368
# 1497           0.028192           0.364064           0.418401
# 1498           0.029689           0.361713           0.412057
# 1499           0.029027           0.355834           0.414286
#
#       right_level1_value  right_level2_value  right_level3_value
# 0               0.260183            0.613552            0.637140
# 1               0.221879            0.610427            0.658160
# 2               0.217780            0.616689            0.669701
# 3               0.237175            0.617966            0.609379
# 4               0.247536            0.612557            0.671341
# ...                  ...                 ...                 ...
# 1495            0.237807            0.622616            0.590706
# 1496            0.230912            0.619894            0.583150
# 1497            0.238638            0.620058            0.637778
# 1498            0.245355            0.617194            0.608817
# 1499            0.243159            0.647151            0.583611
#
# [1500 rows x 6 columns]

# %%
n_subjects = 30
def gen_params_comp_reg(m, df_params, n_subjects):
    '''
    merge the group-level parameters from model fitting with the ground truth of simulation.
    for later plotting and correlation analysis
    This function is for reduced rank model.
    
    Note, need to converte z_trans back to z
    Link: https://groups.google.com/g/hddm-users/c/k0SfUbQ-Tnw
    z = exp(z_trans)/(1+exp(z_trans)) 
    
    '''
    m_traces = m.get_traces()
    
    # create an empty dataframe to store the parameters.
    df_subj_traces = pd.DataFrame(columns = ['params','subj_idx', 'left_level1_value', 'left_level2_value',
                                             'left_level3_value', 'right_level1_value', 'right_level2_value', 
                                             'right_level3_value'])
    for subj_id in range(n_subjects):
        for param in ['v', 'z']:
            if param == 'v':
                # create strings for extracting the traces of 'v' for each condition
                subj_name = 'subj.' + str(subj_id)
                
                # Name for intercept, which is left_level1's parameter
                l_l1_name = 'v' + "_Intercept_" + subj_name 
                # Name for the difference between left_level2 and intercept
                l_l2_eff_name = 'v' + "_C(condition, Treatment('level1'))[T.level2]_" + subj_name 
                # Name for the diff between left_level3 and intercept
                l_l3_eff_name = 'v' + "_C(condition, Treatment('level1'))[T.level3]_" + subj_name 
                # name for the diff between right_level1 and intercept
                r_l1_eff_name = 'v' + "_C(StimType, Treatment('left'))[T.right]_" + subj_name
                # Name for the diff between right_level2 and right_level1 (interaction of right_level2)
                r_l2_int_name = 'v' + "_C(condition, Treatment('level1'))[T.level2]:C(StimType, Treatment('left'))[T.right]_" + subj_name
                # Name for the diff between right_level3 and right_level1 (interaction of right_level3)
                r_l3_int_name = 'v' + "_C(condition, Treatment('level1'))[T.level3]:C(StimType, Treatment('left'))[T.right]_" + subj_name
                
                # get the data (MCMC traces of all these conditions)
                tmp_l_l1 = m_traces[l_l1_name].copy()
                tmp_l_l2 = tmp_l_l1 + m_traces[l_l2_eff_name].copy()
                tmp_l_l3 = tmp_l_l1 + m_traces[l_l3_eff_name].copy()
                tmp_r_l1 = tmp_l_l1 + m_traces[r_l1_eff_name].copy()
                tmp_r_l2 = tmp_r_l1 + m_traces[r_l2_int_name].copy()
                tmp_r_l3 = tmp_r_l1 + m_traces[r_l3_int_name].copy()
            else:
                # create strings for extracting the traces of 'z' for each condition
                subj_name = 'subj.' + str(subj_id)
                l_l1_name = 'z' + "_Intercept_subj_trans." + str(subj_id)
                l_l2_eff_name = 'z' + "_C(condition, Treatment('level1'))[T.level2]_" + subj_name
                l_l3_eff_name = 'z' + "_C(condition, Treatment('level1'))[T.level3]_" + subj_name
                r_l1_eff_name = 'z' + "_C(StimType, Treatment('left'))[T.right]_" + subj_name
                r_l2_int_name = 'z' + "_C(condition, Treatment('level1'))[T.level2]:C(StimType, Treatment('left'))[T.right]_" + subj_name
                r_l3_int_name = 'z' + "_C(condition, Treatment('level1'))[T.level3]:C(StimType, Treatment('left'))[T.right]_" + subj_name

                tmp_l_l1 = m_traces[l_l1_name].copy()
                
                # transfer z_trans to z, using exp(z_trans)/(1+exp(z_trans)), which is equal to 1/(1+np.exp(-x))
                tmp_l_l1 = np.exp(tmp_l_l1)/(1+np.exp(tmp_l_l1))

                tmp_l_l2 = m_traces[l_l2_eff_name].copy()
                tmp_l_l2 = np.exp(tmp_l_l2)/(1+np.exp(tmp_l_l2))

                tmp_l_l3 = tmp_l_l1 + m_traces[l_l3_eff_name].copy()
                tmp_l_l3 = np.exp(tmp_l_l3)/(1+np.exp(tmp_l_l3))

                tmp_r_l1 = tmp_l_l1 + m_traces[r_l1_eff_name].copy()
                tmp_r_l1 = np.exp(tmp_r_l1)/(1+np.exp(tmp_r_l1))

                tmp_r_l2 = tmp_r_l1 + m_traces[r_l2_int_name].copy()
                tmp_r_l2 = np.exp(tmp_r_l2)/(1+np.exp(tmp_r_l2))

                tmp_r_l3 = tmp_r_l1 + m_traces[r_l3_int_name].copy()
                tmp_r_l3 = np.exp(tmp_r_l3)/(1+np.exp(tmp_r_l3))

            # put all these six conditions' mean data together   
            dat= [[param, subj_id, np.mean(tmp_l_l1), np.mean(tmp_l_l2), np.mean(tmp_l_l3), 
                   np.mean(tmp_r_l1), np.mean(tmp_r_l2), np.mean(tmp_r_l3)]]
            
            # create a dataframe from those data
            dd = pd.DataFrame(dat, columns = ['params','subj_idx', 'left_level1_value', 'left_level2_value', 'left_level3_value', 'right_level1_value', 'right_level2_value', 'right_level3_value'])
            
            # append the above as a row for the final dataframe
            df_subj_traces = df_subj_traces.append(dd, ignore_index=True)
                                             

    # melt the dataframe, i.e., wide to long format
    df_subj_traces = pd.melt(df_subj_traces, id_vars=['subj_idx', 'params'], 
                             value_vars=['left_level1_value', 'left_level2_value', 'left_level3_value',
                                         'right_level1_value', 'right_level2_value', 'right_level3_value'])

    df_subj_traces[['StimType','condition','v_name']] = df_subj_traces['variable'].str.split("_",expand=True)
    
    # Long to wide so the v and z are from different columns 
    df_subj_traces = df_subj_traces.pivot_table(index=['subj_idx', 'condition','StimType'], columns='params', values='value')
    df_subj_traces.reset_index(inplace=True) 
    
    # change the data type of 'subj_idx'
    df_subj_traces['subj_idx'] = df_subj_traces['subj_idx'].astype(int)
    df_params_ppc = pd.merge(df_params, df_subj_traces)
    
    return df_params_ppc

# %%
df_params_ppc = gen_params_comp_reg(m4, df_params)
df_params_ppc.head(10)
# Out:
#   condition  subj_idx     a_pop    st_pop    sv_pop    sz_pop     t_pop  \
# 0    level1         0  2.099735  0.149139  0.165144  0.126594  0.328298
# 1    level1         1  1.920791  0.133319  0.015975  0.058869  0.367458
# 2    level1         2  2.015234  0.034590  0.037492  0.243941  0.360005
# 3    level1         3  1.962625  0.095630  0.099299  0.102319  0.265328
# 4    level1         4  1.963466  0.009696  0.031619  0.074624  0.518431
# 5    level1         5  1.994093  0.055814  0.123352  0.058723  0.110663
# 6    level1         6  2.007747  0.000287  0.104315  0.112984  0.407852
# 7    level1         7  2.119132  0.093412  0.071068  0.098720  0.362393
# 8    level1         8  1.901195  0.013551  0.014275  0.114220  0.344928
# 9    level1         9  1.941328  0.120765  0.014519  0.088042  0.334857
#
#       v_pop     z_pop  stimulus StimType         v         z
# 0  1.391437  0.157332         1     left  0.513616  0.034306
# 1  1.436110  0.233952         1     left  0.860625  0.034350
# 2  1.652525  0.171825         1     left  0.871725  0.034214
# 3  1.422619  0.290780         1     left  0.897097  0.034411
# 4  1.475317  0.473331         1     left  1.282883  0.034522
# 5  1.552762  0.272671         1     left  0.933198  0.034368
# 6  1.752137  0.423434         1     left  1.537152  0.034513
# 7  1.614573  0.417595         1     left  1.402093  0.034495
# 8  1.688700  0.350757         1     left  1.534647  0.034564
# 9  1.563807  0.466106         1     left  1.434722  0.034459

# %%
sns.set(style="ticks", color_codes=True, font_scale=1.3)

g = sns.pairplot(df_params_ppc.loc[df_params_ppc['StimType'] == 'left', ['v', 'z', 'v_pop', 'z_pop','condition']], 
                 hue="condition", palette="bright",
                 kind="reg",
                 height = 4, corner=True) # or linewidth=0
plt.setp(g._legend.get_title(), fontsize=18)
# Out:
# [None, None]

# %%
sns.set(style="ticks", color_codes=True, font_scale=1.3)

g = sns.pairplot(df_params_ppc.loc[df_params_ppc['StimType'] == 'right', ['v', 'z', 'v_pop', 'z_pop','condition']], 
                 hue="condition", palette="bright", 
                 #plot_kws=dict(edgecolor='none', alpha=0.5),
                 kind="reg",
                 height = 4, corner=True) # or linewidth=0
plt.setp(g._legend.get_title(), fontsize=18)
# Out:
# [None, None]

# %% [markdown]
# #### M5: Stim-coding + regressor, Way 1
# We treat the data as stimulus-coding with within-subject design.

# %%
def z_link_func(x, data=df_stim):
    stim = (dmatrix('0 + C(s, [[1], [-1]])',
                    {'s':data.stimulus.loc[x.index]},
                    return_type="dataframe")
#    stim = (np.asarray(dmatrix('0 + C(s, [[1], [-1]])',
                               #{'s':data.stimulus.ix[x.index]})) # original .ix is deprecated.
           )
    #print(x.shape)
    return 1/(1+np.exp(-np.multiply(x.to_frame(), stim)))

# %% [markdown]
# And, again, we have two ways to model this situation.
#
# m5 = hddm:HDDMRegressor{ 'v' ~ levels, 'z' ~ levels, link:lamda invlogit_multiplying_sim}

# %%
# z_reg5 = {'model': "z ~ 1 + C(condition,Treatment('level1'))", 
#          'link_func': z_link_func}

# v_reg5 = {'model': "v ~ 1 + C(condition,Treatment('level1'))", 
#          'link_func': lambda x:x}

# reg_descr5 = [z_reg5, v_reg5]

# m5 = hddm.HDDMRegressor(df_stim, reg_descr5, include='z')

# m5.find_starting_values()

# m5.sample(2000, burn=500, dbname='stim_sim_m5.db', db='pickle') 

# # save the model
# m5.save('stim_sim_m5')
# #stim_sim_m5 = hddm.load('stim_sim_m5')

# m5.print_stats()

# %% [markdown]
# #### M6: Stim-coding + regressor, Way 2
#
# Alternatively, we assume the data do not satfifying the model assumption, the pseudo code is like:
#
# m6 = hddm:HDDMRegressor{ 'v' ~ stim * levels, 'z' ~ stim * levels, link:lamda invlogit_multiplying_sim}.

# %%
z_reg6 = {'model': "z ~ 0 + C(condition,Treatment('level1')) * C(StimType, Treatment('left'))", 
         'link_func': z_link_func}

v_reg6 = {'model': "v ~ 0 + C(condition,Treatment('level1')) * C(StimType, Treatment('left'))", 
         'link_func': lambda x:x}

reg_descr6 = [z_reg6, v_reg6]

# need to try group_only_regressors=False ??
m6 = hddm.HDDMRegressor(df_acc, reg_descr6, group_only_regressors=False, keep_regressor_trace=True, include='z')

m6.find_starting_values()

m6.sample(2000, burn=500, dbname='stim_sim_m6.db', db='pickle') # 20180

# save the model
m6.save('stim_sim_m6')

m6.print_stats()
# Out:
# Adding these covariates:
# ["z_C(condition, Treatment('level1'))[level1]", "z_C(condition, Treatment('level1'))[level2]", "z_C(condition, Treatment('level1'))[level3]", "z_C(StimType, Treatment('left'))[T.right]", "z_C(condition, Treatment('level1'))[T.level2]:C(StimType, Treatment('left'))[T.right]", "z_C(condition, Treatment('level1'))[T.level3]:C(StimType, Treatment('left'))[T.right]"]
# Adding these covariates:
# ["v_C(condition, Treatment('level1'))[level1]", "v_C(condition, Treatment('level1'))[level2]", "v_C(condition, Treatment('level1'))[level3]", "v_C(StimType, Treatment('left'))[T.right]", "v_C(condition, Treatment('level1'))[T.level2]:C(StimType, Treatment('left'))[T.right]", "v_C(condition, Treatment('level1'))[T.level3]:C(StimType, Treatment('left'))[T.right]"]
# /opt/conda/lib/python3.7/site-packages/scipy/optimize/optimize.py:1985: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
#  [-----------------100%-----------------] 2001 of 2000 complete in 25727.1 secWARNING: Will not save custom link functions.
# WARNING: Will not save custom link functions.
#                                                                                                     mean         std         2.5q         25q        50q          75q       97.5q       mc err
# a                                                                                                2.00881   0.0252914      1.96013     1.99203    2.00865      2.02542     2.05944   0.00107277
# a_std                                                                                            0.11044   0.0240709    0.0662071   0.0939779   0.108306     0.125944    0.160283   0.00148573
# a_subj.0                                                                                         1.95924   0.0475375      1.86396     1.92708    1.96035      1.98973     2.05472    0.0017639
# a_subj.1                                                                                         1.95381   0.0527431      1.85238     1.91846    1.95338      1.98798     2.06326   0.00182915
# a_subj.2                                                                                         1.82803   0.0510517      1.72904     1.79193     1.8281      1.86282     1.92848   0.00215147
# a_subj.3                                                                                         1.95462   0.0498401      1.85961     1.92107    1.95418      1.98636     2.05175   0.00172346
# a_subj.4                                                                                         1.97534    0.062823      1.86207     1.93056    1.97287      2.01746     2.10079   0.00271311
# a_subj.5                                                                                          1.9459   0.0509485      1.85145     1.91015    1.94542      1.98098     2.05229   0.00206002
_C(condition, Treatment('level1'))[T.level3]:C(StimType, Treatment('left'))[T.right]_subj.29  -0.881939    0.152696     -1.22471   -0.960297  -0.886381    -0.790003   -0.584893    0.0116612
# DIC: 13343.744190
# deviance: 13148.874961
# pD: 194.869229

# %%
#m6 = hddm.load('stim_sim_m6')
# Out:
# WARNING: Custom link functions will not be loaded.

# %%
m = m6
m_traces = m.get_traces()
m_traces.columns[m_traces.columns.str.contains("v_|z_")]
# Out:
# Index(['z_C(condition, Treatment('level1'))[level1]_trans',
#        'z_C(condition, Treatment('level1'))[level1]_std',
#        'z_C(condition, Treatment('level1'))[level1]_subj_trans.0',
#        'z_C(condition, Treatment('level1'))[level1]_subj_trans.1',
#        'z_C(condition, Treatment('level1'))[level1]_subj_trans.2',
#        'z_C(condition, Treatment('level1'))[level1]_subj_trans.3',
#        'z_C(condition, Treatment('level1'))[level1]_subj_trans.4',
#        'z_C(condition, Treatment('level1'))[level1]_subj_trans.5',
#        'z_C(condition, Treatment('level1'))[level1]_subj_trans.6',
#        'z_C(condition, Treatment('level1'))[level1]_subj_trans.7',
#        ...
#        'v_C(condition, Treatment('level1'))[T.level3]:C(StimType, Treatment('left'))[T.right]_subj.20',
#        'v_C(condition, Treatment('level1'))[T.level3]:C(StimType, Treatment('left'))[T.right]_subj.21',
#        'v_C(condition, Treatment('level1'))[T.level3]:C(StimType, Treatment('left'))[T.right]_subj.22',
#        'v_C(condition, Treatment('level1'))[T.level3]:C(StimType, Treatment('left'))[T.right]_subj.23',
#        'v_C(condition, Treatment('level1'))[T.level3]:C(StimType, Treatment('left'))[T.right]_subj.24',
#        'v_C(condition, Treatment('level1'))[T.level3]:C(StimType, Treatment('left'))[T.right]_subj.25',
#        'v_C(condition, Treatment('level1'))[T.level3]:C(StimType, Treatment('left'))[T.right]_subj.26',
#        'v_C(condition, Treatment('level1'))[T.level3]:C(StimType, Treatment('left'))[T.right]_subj.27',
#        'v_C(condition, Treatment('level1'))[T.level3]:C(StimType, Treatment('left'))[T.right]_subj.28',
#        'v_C(condition, Treatment('level1'))[T.level3]:C(StimType, Treatment('left'))[T.right]_subj.29'],
#       dtype='object', length=384)

# %%
df_params_ppc = gen_params_comp_reg(m6, df_params)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'v_Intercept_subj.0'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-77420bc636ab> in <module>
# ----> 1 df_params_ppc = gen_params_comp_reg(m6, df_params)
#
# <ipython-input-21-c3d86d923617> in gen_params_comp_reg(m, df_params)
#      37
#      38                 # get the data (MCMC traces of all these conditions)
# ---> 39                 tmp_l_l1 = m_traces[l_l1_name].copy()
#      40                 tmp_l_l2 = tmp_l_l1 + m_traces[l_l2_eff_name].copy()
#      41                 tmp_l_l3 = tmp_l_l1 + m_traces[l_l3_eff_name].copy()
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'v_Intercept_subj.0'

# %%
sns.set(style="ticks", color_codes=True, font_scale=1.3)

g = sns.pairplot(df_params_ppc.loc[df_params_ppc['StimType'] == 'left', ['v', 'z', 'v_pop', 'z_pop','condition']], 
                 hue="condition", palette="bright", 
                 #plot_kws=dict(edgecolor='none', alpha=0.5),
                 kind="reg",
                 height = 4, corner=True) # or linewidth=0
plt.setp(g._legend.get_title(), fontsize=18)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# [None, None]

# %%
sns.set(style="ticks", color_codes=True, font_scale=1.3)

g = sns.pairplot(df_params_ppc.loc[df_params_ppc['StimType'] == 'right', ['v', 'z', 'v_pop', 'z_pop','condition']], 
                 hue="condition", palette="bright", 
                 #plot_kws=dict(edgecolor='none', alpha=0.5),
                 kind="reg",
                 height = 4, corner=True) # or linewidth=0
plt.setp(g._legend.get_title(), fontsize=18)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# [None, None]

# %% [markdown]
# ## Let's first replicate the tutorial on HDDM website
#
# http://ski.clps.brown.edu/hddm_docs/tutorial_regression_stimcoding.html

# %%
#import sys
# the following will save all the stdout to the txt file, which is not necessary
# sys.stdout = open('ModelRecoveryOutput.txt', 'w')

# %% [markdown]
# ### Creating simulated data for  the experiment
#
# set number of subjects and number of trials per level for the simulated experiment

# %%
n_subjects = 15
trials_per_level = 150

# %% [markdown]
# Next, set up parameters of the DDM for three levels and the first stimulus.

# %%
# level1a = {'v':.3, 'a':2, 't':.3, 'sv':0, 'z':.5, 'sz':0, 'st':0}
# level2a = {'v':.4, 'a':2, 't':.3, 'sv':0, 'z':.6, 'sz':0, 'st':0}
# level3a = {'v':.5, 'a':2, 't':.3, 'sv':0, 'z':.7, 'sz':0, 'st':0}

level1a = {'v':.3, 'a':2, 't':.3, 'sv':0, 'z':.5, 'sz':0, 'st':0}
level2a = {'v':.3, 'a':2, 't':.3, 'sv':0, 'z':.6, 'sz':0, 'st':0}
level3a = {'v':.3, 'a':2, 't':.3, 'sv':0, 'z':.7, 'sz':0, 'st':0}

# %% [markdown]
# Next, set up parameters for the second stimulus, where `v` is the same as for the first stimulus. This is different for `z`. In particular: `z(stimulus_b) = 1 - z(stimulus_a)`.

# %%
level1b = {'v':.4, 'a':2, 't':.3, 'sv':0, 'z':.5, 'sz':0, 'st':0}
level2b = {'v':.5, 'a':2, 't':.3, 'sv':0, 'z':.4, 'sz':0, 'st':0}
level3b = {'v':.6, 'a':2, 't':.3, 'sv':0, 'z':.3, 'sz':0, 'st':0}

# %% [markdown]
# Now, let's generate data for both stimuli

# %%
random.seed(123)
np.random.seed(123)
data_a, params_a = hddm.generate.gen_rand_data({'level1': level1a,
                                                'level2': level2a,
                                                'level3': level3a},
                                              size=trials_per_level,
                                              subjs=n_subjects)

data_b, params_b = hddm.generate.gen_rand_data({'level1': level1b,
                                                'level2': level2b,
                                                'level3': level3b},
                                              size=trials_per_level,
                                              subjs=n_subjects)

# %%
data_a['stimulus'] = pd.Series(np.ones((len(data_a))), index=data_a.index)
data_b['stimulus'] = pd.Series(np.ones((len(data_b)))*2, index=data_a.index)
mydata = data_a.append(data_b,ignore_index=True)

# %%
mydata.head(10)

# %% [markdown]
# ### Setting up the HDDM regression model
#
# The parameter `z` is bound between `0` and `1`, but the standard linear regression does not generate values between `0` and `1`. Therefore, we use a link-function, here the inverse logit $1/(1+exp(-x))$, which transform values between plus and minus infinity into values ranging from (just above) `0` to (nearly) `1`. [this link function is related to logistic regression].
#
# Next, we need to ensure that bias is $z$ for one stimulus and $1-z$ for the other stimulus. To achive this, we can simply multiply the regression output for one stimulus with $-1$. This is implemented here by dot-multiplying the regression output "x" (which is an array) with equally sized array "stim", which is 1 for all stimulus A trials and -1 for stimulus B trials. We use the `patsy` command `dmatrix` to generate such an array from the stimulus column of our stimulated data.
#
# **Note**
# * dot-multiplying is vague here, it should be Hadamard Product, see [here](https://www.tutorialexample.com/understand-numpy-np-multiply-np-dot-and-operation-a-beginner-guide-numpy-tutorial/).

# %%
tmpdata = mydata[mydata['subj_idx'] <= 0]
tmpdata

# %%
stim = (dmatrix('0 + C(s, [[1], [-1]])', 
                {'s':tmpdata.stimulus.loc[tmpdata.index]},
                return_type="dataframe")
        )

#tmp = np.multiply(tmpdata[['stimulus']], stim[:])
tmp = np.multiply(tmpdata.stimulus.loc[tmpdata.index].to_frame(),stim)
#1/(1+np.exp(-((np.asarray(mydata.stimulus.iloc[mydata.index])) * stim)))
type(stim)
#stim.index
#type(mydata.stimulus.iloc[mydata.index])

# %%
tmp

# %%
tmp2 = tmpdata.stimulus.loc[tmpdata.index]
tmp2.to_frame().shape

# %%
# x is a pandas Series, it should be converted to dataframe to do the multiplication.

def z_link_func(x, data=mydata):
    stim = (dmatrix('0 + C(s, [[1], [-1]])',
                    {'s':data.stimulus.loc[x.index]},
                    return_type="dataframe")
#    stim = (np.asarray(dmatrix('0 + C(s, [[1], [-1]])',
                               #{'s':data.stimulus.ix[x.index]})) # original .ix is deprecated.
           )
    #print(x.shape)
    return 1/(1+np.exp(-np.multiply(x.to_frame(), stim)))
    #return 1 /( 1+np.exp(-(x * stim)))

# %%
# x is a pandas Series, it should be converted to dataframe to do the multiplication.

def v_link_func(x, data=mydata):
    stim = (dmatrix('0 + C(s, [[1], [-1]])',
                    {'s':data.stimulus.loc[x.index]},
                    return_type="dataframe")
#    stim = (np.asarray(dmatrix('0 + C(s, [[1], [-1]])',
                               #{'s':data.stimulus.ix[x.index]})) # original .ix is deprecated.
           )
    #print(x.shape)
    return np.multiply(x.to_frame(), stim)
    #return 1 /( 1+np.exp(-(x * stim)))

# %% [markdown]
# Now, we set up the regression models for `z` and `v` and also include the link functions. The relevant string here used by `patsy` is `1 + C(condition)`. This will generate a design matrix with an intercept (that's what the `1` is for) and two dummy variables for remaining levels. (The column in which the levels are coded has the default name `condition`):
#
# **NOTE: there is only one variable used in the modelling**

# %%
z_reg = {'model': 'z ~ 1 + C(condition)', 'link_func':z_link_func}

# %% [markdown]
# For `v` the link function is simply $x = x$, b/c no transformation is needed. (However, you could also analyze this experiment with response coded data. Then you would not stimulus code `z` but `v` and you would have to multiply the `v` for one condition with `-1`, with a link function like the one for `z`, but without the additional logit transform):

# %%
v_reg = {'model': 'v ~ 1 + C(condition)', 'link_func': lambda x:x}

# %% [markdown]
# Now, we can finally put the regression description for the hddm model together. The general for this is `[{'model': 'outcome_parameter ~ patsy_design_string', 'link_func': your_link_func}, {...}, ...]`

# %%
reg_descr = [z_reg, v_reg]

# %% [markdown]
# The last step before running the model is to construct the complete hddm regression model by adding data etc.

# %%
m_reg = hddm.HDDMRegressor(mydata, reg_descr, include='z')

# %% [markdown]
# Now, we start the sampling, which takes a long time

# %%
m_reg.sample(1000, burn=200, dbname='within_effect.db', db='pickle')

# %%
m_reg.save('within_effect')

# %%
m_reg.plot_posteriors()

# %%
m_reg.print_stats()

# %%
v_reg2 = {'model': 'v ~ 1 + C(condition)', 'link_func': v_link_func}

# %%
reg_descr2 = [z_reg, v_reg2]
m_reg2 = hddm.HDDMRegressor(mydata, reg_descr2, include='z')
m_reg2.sample(1000, burn=200, dbname='within_effect2.db', db='pickle') 
m_reg2.save('within_effect2')

# %%
m_reg2.print_stats()

# %% [markdown]
# **What if we model as I did?**
#
# First, add the reponse type as an other variable

# %%
mydata2 = mydata
# df.loc[df['salary'] > 50, 'is_rich'] = 'yes'
# https://www.dataquest.io/blog/tutorial-add-column-pandas-dataframe-based-on-if-else-condition/
# df['hasimage'] = np.where(df['photos']!= '[]', True, False) 
mydata2['StimType'] = np.where(mydata2['stimulus'] == 1.0, 'left', 'right')
# mydata2.loc[mydata2['stimulus'] == 0,'StimType'] = 'right'

# %%
mydata2.head(10)

# %%
z_reg2 = {'model': "z ~ 1 + C(condition,Treatment('level1')) * C(StimType, Treatment('left'))", 'link_func':z_link_func}
v_reg2 = {'model': "v ~ 1 + C(condition,Treatment('level1')) * C(StimType, Treatment('left'))", 'link_func': lambda x:x}
reg_descr2 = [z_reg2, v_reg2]

# %%
# check the design matrix
dmatrix("C(condition,Treatment('level1')) * C(StimType, Treatment('left'))", 
        {'condition':mydata2['condition'], 'StimType':mydata2['StimType']})

# %%
m_reg2 = hddm.HDDMRegressor(mydata2, reg_descr2, include='z')

# %%
m_reg2.sample(1000, burn=200, dbname='within_effect2.db', db='pickle') 
m_reg2.save('within_effect2')
m_reg2.plot_posteriors()

# %%
m_reg2 = hddm.load("within_effect2")

# %%
m_reg2_trace = m_reg2.get_group_traces()
print(m_reg2_trace.shape)
m_reg2_trace.head(10)

# %%
# rename the columns
import re

lst = ["v_", "z_", "t(", 'cha']
esc_lst = [re.escape(s) for s in lst]
pattern = '|'.join(esc_lst)

# select v, a, t, and chains
slct_columns = m_reg2_trace.columns[m_reg2_trace.columns.str.contains(pattern, case=False)]

slct_columns = [ x for x in slct_columns if "std" not in x ]

df_tmp = m_reg2_trace[slct_columns]
df_tmp.head(10)

# %%
df_tmp.columns = ['z_intercept', 'z_effect_L2', 'z_effect_L3', 'z_effect_left', 'z_L2:left', 'z_L3:left',
                  'v_intercept', 'v_effect_L2', 'v_effect_L3', 'v_effect_left', 'v_L2:left', 'v_L3:left'] 
df_tmp.head(10)

# %%
df_tmp.loc[:,'v_L1_left'] = df_tmp.loc[:,'v_intercept'].copy()
df_tmp.loc[:,'v_L2_left']  = df_tmp.loc[:,'v_intercept'].copy() + df_tmp.loc[:, 'v_effect_L2'].copy()
df_tmp.loc[:,'v_L3_left'] = df_tmp.loc[:,'v_intercept'].copy() + df_tmp.loc[:, 'v_effect_L3'].copy()
df_tmp.loc[:,'v_L1_right']  = df_tmp.loc[:,'v_intercept'].copy() + df_tmp.loc[:, 'v_effect_left'].copy()
df_tmp.loc[:,'v_L2_right']   = df_tmp.loc[:,'v_intercept'].copy() + df_tmp.loc[:, 'v_effect_left'].copy() + df_tmp.loc[:, 'v_L2:left'].copy()
df_tmp.loc[:,'v_L3_right']  = df_tmp.loc[:,'v_intercept'].copy() + df_tmp.loc[:, 'v_effect_left'].copy() + df_tmp.loc[:, 'v_L3:left'].copy()

# %%
df_tmp.head()

# %%
df_tmp_v = df_tmp[['v_L1_left', 'v_L2_left', 'v_L3_left', 'v_L1_right', 'v_L2_right', 'v_L3_right']]
df_tmp_v.head(10)

# %%
df_tmp_v.plot.density(figsize=(8,6),xlim=(-2.5, 3.5),linewidth=3)

# %% [markdown]
# ### Comparing generative and recovered model parameters
# First, let's print the model stats

# %%
m_reg.print_stats()

# %% [markdown]
# ## Working with real data
#
# Now let's move to the real data.
#
# I will use 1b as the example because it includes many scale data. I'd like to try whether we can add these scores as an group-level predictor.
#
#
# I will first model the data as the tutorial about within-subject design and stimulus-coding, then I will add the self-esteem as an additional regressor.

# %%
# load data
df1b = hddm.load_csv('df1bv.hddm_stim.reg.csv')
df = df1b

# randomly chose 10 participants from the dataset
df_subj = df['subj_idx'].unique()
random.seed(10)
df_test_list = []
for i in range(10):
    pos = random.randint(0, (len(df_subj)-1))
    df_test_list.append(df_subj[pos])  

df_test = df[df['subj_idx'].isin(df_test_list)]

# %%
df_test.head(10)

# %%
# create a link func for z
def z_link_func(x, data=df_test):
    stim = (dmatrix('0 + C(s, [[1], [-1]])',
                    {'s':data.stim.loc[x.index]},
                    return_type="dataframe")
           )
    return 1/(1+np.exp(-np.multiply(x.to_frame(), stim)))

# %% [markdown]
# ### Stimulus coding in regressor
#
# This time, explicitly used `C` to indicate the independent variables are categorical.

# %%
z_reg = {'model': "z ~ 1 + C(match,Treatment('Mismatch')) * C(val, Treatment('Neutral'))", 'link_func': z_link_func}

# %%
# check the design matrix
# without self-esteem as a regressor
dmatrix("C(match,Treatment('Mismatch')) * C(val, Treatment('Neutral'))", {'match':df_test['match'], 'val':df_test['val']})

# with self-esteem as regressor
#dmatrix("SlfEst_sum:C(match,Treatment('Mismatch')) * C(val, Treatment('Neutral'))", {'SlfEst_sum':df_test['SlfEst_sum'], 'match':df_test['match'], 'val':df_test['val']})

# %%
z_reg = {'model': "z ~ 1 + C(match,Treatment('Mismatch')) * C(val, Treatment('Neutral'))", 'link_func': z_link_func}
v_reg = {'model': "v ~ 1 + C(match,Treatment('Mismatch')) * C(val, Treatment('Neutral'))", 'link_func': lambda x:x}
a_reg = {'model': "a ~ 1 + C(match,Treatment('Mismatch')) * C(val, Treatment('Neutral'))", 'link_func': lambda x:x}

reg_descr = [z_reg, v_reg, a_reg]

m_reg = hddm.HDDMRegressor(df_test, v_reg, include='z')

# %%
start_time = time.time()   # the start time of the processing

m_reg.sample(5000, burn=1000, dbname='df1_within_effect_try.db', db='pickle') 

print("\nRunning within model of exp 1a (10 subj) used: %f seconds" % (time.time() - start_time)) # print the elapse of time

# %%
m_reg.save('df1_within_effect_try')

# %%
m_reg.plot_posteriors()

# %%
print("m_reg DIC: %f" % m_reg.dic)

# %%
stats = m_reg.gen_stats()
stats

# %%
v_nmn, v_nmg, v_nmb = m_reg.nodes_db.loc[["v_Intercept",
                                              "v_C(val, Treatment('Neutral'))[T.Bad]",
                                              "v_C(val, Treatment('Neutral'))[T.Good]"], 'node']
#v_nmg = v_nmn + v_nmg
#v_nmb = v_nmn + v_nmb
hddm.analyze.plot_posterior_nodes([v_nmn, v_nmg, v_nmb])
plt.xlabel('drift-rate')
plt.ylabel('Posterior probability')
plt.title('Group mean posteriors of within-subject drift-rate effects.')

# %%
v_mn, v_mg, v_mb = m_reg.nodes_db.loc[["v_C(match, Treatment('Mismatch'))[T.Match]",
                                              "v_C(match, Treatment('Mismatch'))[T.Match]:C(val, Treatment('Neutral'))[T.Bad]",
                                              "v_C(match, Treatment('Mismatch'))[T.Match]:C(val, Treatment('Neutral'))[T.Good]"], 'node']
#v_nmg = v_nmn + v_nmg
#v_nmb = v_nmn + v_nmb
hddm.analyze.plot_posterior_nodes([v_mn, v_mg, v_mb])
plt.xlabel('drift-rate')
plt.ylabel('Posterior probability')
plt.title('Group mean posteriors of within-subject drift-rate effects.')

# %%
m_reg_trace = m_reg.get_group_traces()
print(m_reg_trace.shape)

# %%
m_reg_trace.head(10)

# %%
# rename the columns
import re

lst = ["v_", "a(", "t(", 'cha']
esc_lst = [re.escape(s) for s in lst]
pattern = '|'.join(esc_lst)

# select v, a, t, and chains
slct_columns = m_reg_trace.columns[m_reg_trace.columns.str.contains(pattern, case=False)]

slct_columns = [ x for x in slct_columns if "std" not in x ]

df_tmp = m_reg_trace[slct_columns]
df_tmp.head(10)

# %%
df_tmp.columns = ['v_intercept', 'v_effect_Match', 'v_effect_NM_Bad', 'v_effect_NM_Good', 'v_Match:Bad', 'v_Match:Good'] 
df_tmp.head(10)

# %%
df_tmp.loc[:,'NM_Neut'] = df_tmp.loc[:,'v_intercept'].copy() + df_tmp.loc[:, 'v_effect_NM_Bad'].copy()

# %%
df_tmp.loc[:,'NM_Neut'] = df_tmp.loc[:,'v_intercept'].copy()
df_tmp.loc[:,'NM_Bad']  = df_tmp.loc[:,'v_intercept'].copy() + df_tmp.loc[:, 'v_effect_NM_Bad'].copy()
df_tmp.loc[:,'NM_Good'] = df_tmp.loc[:,'v_intercept'].copy() + df_tmp.loc[:, 'v_effect_NM_Good'].copy()
df_tmp.loc[:,'M_Neut']  = df_tmp.loc[:,'v_intercept'].copy() + df_tmp.loc[:, 'v_effect_Match'].copy()
df_tmp.loc[:,'M_Bad']   = df_tmp.loc[:,'v_intercept'].copy() + df_tmp.loc[:, 'v_effect_Match'].copy() + df_tmp.loc[:, 'v_Match:Bad'].copy()
df_tmp.loc[:,'M_Good']  = df_tmp.loc[:,'v_intercept'].copy() + df_tmp.loc[:, 'v_effect_Match'].copy() + df_tmp.loc[:, 'v_Match:Good'].copy()

# %%
df_tmp = df_tmp.loc[:, ['NM_Neut', 'NM_Bad', 'NM_Good', 'M_Neut', 'M_Bad', 'M_Good']]
df_tmp.head(10)

# %%
df_tmp.plot.density(figsize=(8,6),xlim=(-2.5, 3.5),linewidth=3)

# %%
df_tmp["id"] = df_tmp.index
# df_tmp.head()
print('Shape of the wide format', df_tmp.shape)

df_melt = pd.melt(df_tmp,
                  id_vars=['id'],
                  value_vars=['NM_Neut', 'NM_Bad', 'NM_Good', 'M_Neut', 'M_Bad', 'M_Good'],
                  var_name='cond',
                  value_name='value')

#type(df_melt)
print('Shape of the long format', df_melt.shape)
df_melt.head()

# %%
# split the cond column into three columns
df_melt[['Matchness','Valence']] = pd.DataFrame(df_melt['cond'].apply(lambda x: [i for i in re.split(r'[\_\.]', x) if len(i)>0]).to_list())
df_melt.head()

# %%
df_melt['cond_c'] = pd.Categorical(df_melt['cond'], categories=['NM_Bad', 'NM_Neut', 'NM_Good', 'M_Bad', 'M_Neut',  'M_Good'])

import seaborn as sns
sns.kdeplot(data=df_melt, x="value", hue="cond_c")
